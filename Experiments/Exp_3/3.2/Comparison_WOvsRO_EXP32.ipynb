# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter  , ScalarFormatter
import matplotlib.axes as ax
import numpy as np
import statistics as st

MODE = 'W'
E = '3'
E_e = '3.2'
EXP = '32'

threads = 1
num_client_machines = 3
#clients=(1 8 16 22 28 32 40 50 60 100 300 500)
connections_per_thread = [1, 8, 16, 22, 28, 32]

clients = []

for c in connections_per_thread:
    clients.append(c*threads*num_client_machines)
clients

path_8threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/8_threads/'
path_16threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/16_threads/'
path_32threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/32_threads/'
path_64threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/64_threads/'

# %%
## This puts in the map every measure for different number of connection_per_thread and every try.

#Throughput
WOthroughput_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOthroughput_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOthroughput_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOthroughput_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOthroughput_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOthroughput_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOthroughput_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOthroughput_64threads_std_M1 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_8threads_avg_M1.get(n_try).append(float(avg))
            WOthroughput_8threads_std_M1.get(n_try).append(float(std))

    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_16threads_avg_M1.get(n_try).append(float(avg))
            WOthroughput_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_32threads_avg_M1.get(n_try).append(float(avg))
            WOthroughput_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_64threads_avg_M1.get(n_try).append(float(avg))
            WOthroughput_64threads_std_M1.get(n_try).append(float(std))

# %%
# Put data of queueLenght in corresponding Maps.

#Queue Lenght
WOqueueLenght_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOqueueLenght_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOqueueLenght_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOqueueLenght_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOqueueLenght_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOqueueLenght_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOqueueLenght_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOqueueLenght_64threads_std_M1 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_8threads_avg_M1.get(n_try).append(float(avg))
            WOqueueLenght_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_16threads_avg_M1.get(n_try).append(float(avg))
            WOqueueLenght_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_32threads_avg_M1.get(n_try).append(float(avg))
            WOqueueLenght_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_64threads_avg_M1.get(n_try).append(float(avg))
            WOqueueLenght_64threads_std_M1.get(n_try).append(float(std))

# %%
# Put data of Waiting Time in corresponding Maps.

#Waiting Time
WOWaitingTime_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOWaitingTime_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOWaitingTime_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOWaitingTime_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOWaitingTime_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOWaitingTime_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOWaitingTime_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOWaitingTime_64threads_std_M1 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_8threads_avg_M1.get(n_try).append(float(avg))
            WOWaitingTime_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_16threads_avg_M1.get(n_try).append(float(avg))
            WOWaitingTime_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_32threads_avg_M1.get(n_try).append(float(avg))
            WOWaitingTime_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_64threads_avg_M1.get(n_try).append(float(avg))
            WOWaitingTime_64threads_std_M1.get(n_try).append(float(std))

# %%
# Put data of Service Time in corresponding Maps.

#Service Time

WOServiceTime_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOServiceTime_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOServiceTime_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOServiceTime_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOServiceTime_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOServiceTime_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOServiceTime_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOServiceTime_64threads_std_M1 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_8threads_avg_M1.get(n_try).append(float(avg))
            WOServiceTime_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_16threads_avg_M1.get(n_try).append(float(avg))
            WOServiceTime_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_32threads_avg_M1.get(n_try).append(float(avg))
            WOServiceTime_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_64threads_avg_M1.get(n_try).append(float(avg))
            WOServiceTime_64threads_std_M1.get(n_try).append(float(std))

# %%
#Parse Time
WOParseTime_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOParseTime_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOParseTime_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOParseTime_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOParseTime_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOParseTime_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOParseTime_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOParseTime_64threads_std_M1 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_8threads_avg_M1.get(n_try).append(float(avg))
            WOParseTime_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_16threads_avg_M1.get(n_try).append(float(avg))
            WOParseTime_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_32threads_avg_M1.get(n_try).append(float(avg))
            WOParseTime_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_64threads_avg_M1.get(n_try).append(float(avg))
            WOParseTime_64threads_std_M1.get(n_try).append(float(std))

# %%
print("Throughput 8 threads: "+str(len(WOthroughput_8threads_avg_M1.get(n_try))))
print("Throughput 16 threads: "+str(len(WOthroughput_16threads_avg_M1.get(n_try))))
print("Throughput 32 threads: "+str(len(WOthroughput_32threads_avg_M1.get(n_try))))
print("Throughput 64 threads: "+str(len(WOthroughput_64threads_avg_M1.get(n_try))))


print("Queue Lenght 8 threads: "+str(len(WOqueueLenght_8threads_std_M1.get(n_try))))
print("Queue Lenght 16 threads: "+str(len(WOqueueLenght_16threads_std_M1.get(n_try))))
print("Queue Lenght 32 threads: "+str(len(WOqueueLenght_32threads_std_M1.get(n_try))))
print("Queue Lenght 64 threads: "+str(len(WOqueueLenght_64threads_std_M1.get(n_try))))

print("Waiting Time Lenght 8 threads: "+str(len(WOWaitingTime_8threads_std_M1.get(n_try))))
print("Waiting Time Lenght 16 threads: "+str(len(WOWaitingTime_16threads_std_M1.get(n_try))))
print("Waiting Time Lenght 32 threads: "+str(len(WOWaitingTime_32threads_std_M1.get(n_try))))
print("Waiting Time Lenght 64 threads: "+str(len(WOWaitingTime_64threads_std_M1.get(n_try))))

print("Service Time Lenght 8 threads: "+str(len(WOServiceTime_8threads_std_M1.get(n_try))))
print("Service Time Lenght 16 threads: "+str(len(WOServiceTime_16threads_std_M1.get(n_try))))
print("Service Time Lenght 32 threads: "+str(len(WOServiceTime_32threads_std_M1.get(n_try))))
print("Service Time Lenght 64 threads: "+str(len(WOServiceTime_64threads_std_M1.get(n_try))))

print("Parse Time Lenght 8 threads: "+str(len(WOParseTime_8threads_std_M1.get(n_try))))
print("Parse Time Lenght 16 threads: "+str(len(WOParseTime_16threads_std_M1.get(n_try))))
print("Parse Time Lenght 32 threads: "+str(len(WOParseTime_32threads_std_M1.get(n_try))))
print("Parse Time Lenght 64 threads: "+str(len(WOParseTime_64threads_std_M1.get(n_try))))
# Out:
# Throughput 8 threads: 6
# Throughput 16 threads: 6
# Throughput 32 threads: 6
# Throughput 64 threads: 6
# Queue Lenght 8 threads: 6
# Queue Lenght 16 threads: 6
# Queue Lenght 32 threads: 6
# Queue Lenght 64 threads: 6
# Waiting Time Lenght 8 threads: 6
# Waiting Time Lenght 16 threads: 6
# Waiting Time Lenght 32 threads: 6
# Waiting Time Lenght 64 threads: 6
# Service Time Lenght 8 threads: 6
# Service Time Lenght 16 threads: 6
# Service Time Lenght 32 threads: 6
# Service Time Lenght 64 threads: 6
# Parse Time Lenght 8 threads: 6
# Parse Time Lenght 16 threads: 6
# Parse Time Lenght 32 threads: 6
# Parse Time Lenght 64 threads: 6

# %%
#Now calculate the following

WOlatencies_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOlatencies_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOlatencies_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOlatencies_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOlatencies_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOlatencies_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOlatencies_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOlatencies_64threads_std_M1 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    for i in range(0,len(WOParseTime_8threads_avg_M1.get(n_try)),1):
        WOlatencies_8threads_avg_M1.get(n_try).append(    WOParseTime_8threads_avg_M1.get(n_try)[i] + 
                                                          WOWaitingTime_8threads_avg_M1.get(n_try)[i] +
                                                          WOServiceTime_8threads_avg_M1.get(n_try)[i]
                                                     )
        WOlatencies_8threads_std_M1.get(n_try).append(    WOParseTime_8threads_std_M1.get(n_try)[i] + 
                                                          WOWaitingTime_8threads_std_M1.get(n_try)[i] +
                                                          WOServiceTime_8threads_std_M1.get(n_try)[i]
                                                     )
    for i in range(0,len(WOParseTime_16threads_avg_M1.get(n_try)),1):       
        WOlatencies_16threads_avg_M1.get(n_try).append(    WOParseTime_16threads_avg_M1.get(n_try)[i] + 
                                                          WOWaitingTime_16threads_avg_M1.get(n_try)[i] +
                                                          WOServiceTime_16threads_avg_M1.get(n_try)[i]
                                                     )
        
        WOlatencies_16threads_std_M1.get(n_try).append(    WOParseTime_16threads_std_M1.get(n_try)[i] + 
                                                          WOWaitingTime_16threads_std_M1.get(n_try)[i] +
                                                          WOServiceTime_16threads_std_M1.get(n_try)[i]
                                                     )
    for i in range(0,len(WOParseTime_32threads_avg_M1.get(1)),1):               
        WOlatencies_32threads_avg_M1.get(n_try).append(    WOParseTime_32threads_avg_M1.get(n_try)[i] + 
                                                          WOWaitingTime_32threads_avg_M1.get(n_try)[i] +
                                                          WOServiceTime_32threads_avg_M1.get(n_try)[i]
                                                     )
        
        WOlatencies_32threads_std_M1.get(n_try).append(    WOParseTime_32threads_std_M1.get(n_try)[i] + 
                                                          WOWaitingTime_32threads_std_M1.get(n_try)[i] +
                                                          WOServiceTime_32threads_std_M1.get(n_try)[i]
                                                     )

    for i in range(0,len(WOParseTime_64threads_avg_M1.get(1)),1):               
        WOlatencies_64threads_avg_M1.get(n_try).append(    WOParseTime_64threads_avg_M1.get(n_try)[i] + 
                                                          WOWaitingTime_64threads_avg_M1.get(n_try)[i] +
                                                          WOServiceTime_64threads_avg_M1.get(n_try)[i]
                                                     )
        
        WOlatencies_64threads_std_M1.get(n_try).append(    WOParseTime_64threads_std_M1.get(n_try)[i] + 
                                                          WOWaitingTime_64threads_std_M1.get(n_try)[i] +
                                                          WOServiceTime_64threads_std_M1.get(n_try)[i]
                                                     )

# %%
WOlatencies_8threads_avg_M1 = np.mean([ WOlatencies_8threads_avg_M1.get(1), WOlatencies_8threads_avg_M1.get(2), WOlatencies_8threads_avg_M1.get(3) ], axis=0)
WOlatencies_8threads_std_M1 = np.mean([ WOlatencies_8threads_std_M1.get(1), WOlatencies_8threads_std_M1.get(2), WOlatencies_8threads_std_M1.get(3) ], axis=0)

WOlatencies_16threads_avg_M1 = np.mean([ WOlatencies_16threads_avg_M1.get(1), WOlatencies_16threads_avg_M1.get(2), WOlatencies_16threads_avg_M1.get(3) ], axis=0)
WOlatencies_16threads_std_M1 = np.mean([ WOlatencies_16threads_std_M1.get(1), WOlatencies_16threads_std_M1.get(2), WOlatencies_16threads_std_M1.get(3) ], axis=0)

WOlatencies_32threads_avg_M1 = np.mean([ WOlatencies_32threads_avg_M1.get(1), WOlatencies_32threads_avg_M1.get(2), WOlatencies_32threads_avg_M1.get(3) ], axis=0)
WOlatencies_32threads_std_M1 = np.mean([ WOlatencies_32threads_std_M1.get(1), WOlatencies_32threads_std_M1.get(2), WOlatencies_32threads_std_M1.get(3) ], axis=0)

WOlatencies_64threads_avg_M1 = np.mean([ WOlatencies_64threads_avg_M1.get(1), WOlatencies_64threads_avg_M1.get(2), WOlatencies_64threads_avg_M1.get(3) ], axis=0)
WOlatencies_64threads_std_M1 = np.mean([ WOlatencies_64threads_std_M1.get(1), WOlatencies_64threads_std_M1.get(2), WOlatencies_64threads_std_M1.get(3) ], axis=0)




WOthroughput_8threads_avg_M1 = np.mean([ WOthroughput_8threads_avg_M1.get(1), WOthroughput_8threads_avg_M1.get(2), WOthroughput_8threads_avg_M1.get(3) ], axis=0)
WOthroughput_8threads_std_M1 = np.mean([ WOthroughput_8threads_std_M1.get(1), WOthroughput_8threads_std_M1.get(2), WOthroughput_8threads_std_M1.get(3) ], axis=0)

WOthroughput_16threads_avg_M1 = np.mean([ WOthroughput_16threads_avg_M1.get(1), WOthroughput_16threads_avg_M1.get(2), WOthroughput_16threads_avg_M1.get(3) ], axis=0)
WOthroughput_16threads_std_M1 = np.mean([ WOthroughput_16threads_std_M1.get(1), WOthroughput_16threads_std_M1.get(2), WOthroughput_16threads_std_M1.get(3) ], axis=0)

WOthroughput_32threads_avg_M1 = np.mean([ WOthroughput_32threads_avg_M1.get(1), WOthroughput_32threads_avg_M1.get(2), WOthroughput_32threads_avg_M1.get(3) ], axis=0)
WOthroughput_32threads_std_M1 = np.mean([ WOthroughput_32threads_std_M1.get(1), WOthroughput_32threads_std_M1.get(2), WOthroughput_32threads_std_M1.get(3) ], axis=0)

WOthroughput_64threads_avg_M1 = np.mean([ WOthroughput_64threads_avg_M1.get(1), WOthroughput_64threads_avg_M1.get(2), WOthroughput_64threads_avg_M1.get(3) ], axis=0)
WOthroughput_64threads_std_M1 = np.mean([ WOthroughput_64threads_std_M1.get(1), WOthroughput_64threads_std_M1.get(2), WOthroughput_64threads_std_M1.get(3) ], axis=0)




WOqueueLenght_8threads_avg_M1 = np.mean([ WOqueueLenght_8threads_avg_M1.get(1), WOqueueLenght_8threads_avg_M1.get(2), WOqueueLenght_8threads_avg_M1.get(3) ], axis=0)
WOqueueLenght_8threads_std_M1 = np.mean([ WOqueueLenght_8threads_std_M1.get(1), WOqueueLenght_8threads_std_M1.get(2), WOqueueLenght_8threads_std_M1.get(3) ], axis=0)

WOqueueLenght_16threads_avg_M1 = np.mean([ WOqueueLenght_16threads_avg_M1.get(1), WOqueueLenght_16threads_avg_M1.get(2), WOqueueLenght_16threads_avg_M1.get(3) ], axis=0)
WOqueueLenght_16threads_std_M1 = np.mean([ WOqueueLenght_16threads_std_M1.get(1), WOqueueLenght_16threads_std_M1.get(2), WOqueueLenght_16threads_std_M1.get(3) ], axis=0)

WOqueueLenght_32threads_avg_M1 = np.mean([ WOqueueLenght_32threads_avg_M1.get(1), WOqueueLenght_32threads_avg_M1.get(2), WOqueueLenght_32threads_avg_M1.get(3) ], axis=0)
WOqueueLenght_32threads_std_M1 = np.mean([ WOqueueLenght_32threads_std_M1.get(1), WOqueueLenght_32threads_std_M1.get(2), WOqueueLenght_32threads_std_M1.get(3) ], axis=0)

WOqueueLenght_64threads_avg_M1 = np.mean([ WOqueueLenght_64threads_avg_M1.get(1), WOqueueLenght_64threads_avg_M1.get(2), WOqueueLenght_64threads_avg_M1.get(3) ], axis=0)
WOqueueLenght_64threads_std_M1 = np.mean([ WOqueueLenght_64threads_std_M1.get(1), WOqueueLenght_64threads_std_M1.get(2), WOqueueLenght_64threads_std_M1.get(3) ], axis=0)

# %%
WOService_time_8threads_avg_M1 = np.mean([ WOServiceTime_8threads_avg_M1.get(1),WOServiceTime_8threads_avg_M1.get(2),WOServiceTime_8threads_avg_M1.get(3) ], axis=0)
WOService_time_8threads_std_M1 = np.mean([ WOServiceTime_8threads_std_M1.get(1),WOServiceTime_8threads_std_M1.get(2),WOServiceTime_8threads_std_M1.get(3) ], axis=0)

WOService_time_16threads_avg_M1 = np.mean([ WOServiceTime_16threads_avg_M1.get(1),WOServiceTime_16threads_avg_M1.get(2),WOServiceTime_16threads_avg_M1.get(3) ], axis=0)
WOService_time_16threads_std_M1 = np.mean([ WOServiceTime_16threads_std_M1.get(1),WOServiceTime_16threads_std_M1.get(2),WOServiceTime_16threads_std_M1.get(3) ], axis=0)

WOService_time_32threads_avg_M1 = np.mean([ WOServiceTime_32threads_avg_M1.get(1),WOServiceTime_32threads_avg_M1.get(2),WOServiceTime_32threads_avg_M1.get(3) ], axis=0)
WOService_time_32threads_std_M1 = np.mean([ WOServiceTime_32threads_std_M1.get(1),WOServiceTime_32threads_std_M1.get(2),WOServiceTime_32threads_std_M1.get(3) ], axis=0)

WOService_time_64threads_avg_M1 = np.mean([ WOServiceTime_64threads_avg_M1.get(1),WOServiceTime_64threads_avg_M1.get(2),WOServiceTime_64threads_avg_M1.get(3) ], axis=0)
WOService_time_64threads_std_M1 = np.mean([ WOServiceTime_64threads_std_M1.get(1),WOServiceTime_64threads_std_M1.get(2),WOServiceTime_64threads_std_M1.get(3) ], axis=0)

WOWaiting_time_8threads_avg_M1 = np.mean([ WOWaitingTime_8threads_avg_M1.get(1),WOWaitingTime_8threads_avg_M1.get(2),WOWaitingTime_8threads_avg_M1.get(3) ], axis=0)
WOWaiting_time_8threads_std_M1 = np.mean([ WOWaitingTime_8threads_std_M1.get(1),WOWaitingTime_8threads_std_M1.get(2),WOWaitingTime_8threads_std_M1.get(3) ], axis=0)

WOWaiting_time_16threads_avg_M1 = np.mean([ WOWaitingTime_16threads_avg_M1.get(1),WOWaitingTime_16threads_avg_M1.get(2),WOWaitingTime_16threads_avg_M1.get(3) ], axis=0)
WOWaiting_time_16threads_std_M1 = np.mean([ WOWaitingTime_16threads_std_M1.get(1),WOWaitingTime_16threads_std_M1.get(2),WOWaitingTime_16threads_std_M1.get(3) ], axis=0)

WOWaiting_time_32threads_avg_M1 = np.mean([ WOWaitingTime_32threads_avg_M1.get(1),WOWaitingTime_32threads_avg_M1.get(2),WOWaitingTime_32threads_avg_M1.get(3) ], axis=0)
WOWaiting_time_32threads_std_M1 = np.mean([ WOWaitingTime_32threads_std_M1.get(1),WOWaitingTime_32threads_std_M1.get(2),WOWaitingTime_32threads_std_M1.get(3) ], axis=0)

WOWaiting_time_64threads_avg_M1 = np.mean([ WOWaitingTime_64threads_avg_M1.get(1),WOWaitingTime_64threads_avg_M1.get(2),WOWaitingTime_64threads_avg_M1.get(3) ], axis=0)
WOWaiting_time_64threads_std_M1 = np.mean([ WOWaitingTime_64threads_std_M1.get(1),WOWaitingTime_64threads_std_M1.get(2),WOWaitingTime_64threads_std_M1.get(3) ], axis=0)

# %%
#To calculate.

WOideal_throughput_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_throughput_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOideal_throughput_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_throughput_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOideal_throughput_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_throughput_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOideal_throughput_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_throughput_64threads_std_M1 = {1:[], 2:[], 3:[]}



WOideal_latencies_8threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_latencies_8threads_std_M1 = {1:[], 2:[], 3:[]}

WOideal_latencies_16threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_latencies_16threads_std_M1 = {1:[], 2:[], 3:[]}

WOideal_latencies_32threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_latencies_32threads_std_M1 = {1:[], 2:[], 3:[]}

WOideal_latencies_64threads_avg_M1 = {1:[], 2:[], 3:[]}
WOideal_latencies_64threads_std_M1 = {1:[], 2:[], 3:[]}

# %% [markdown]
# WOthroughput_8threads_avg_M1       WOthroughput_8threads_std_M1
# WOthroughput_16threads_avg_M1      WOthroughput_16threads_std_M1
# WOthroughput_32threads_avg_M1      WOthroughput_32threads_std_M1
# WOthroughput_64threads_avg_M1      WOthroughput_64threads_std_M1
#
#
# WOqueueLenght_8threads_avg_M1     WOqueueLenght_8threads_std_M1
# WOqueueLenght_16threads_avg_M1    WOqueueLenght_16threads_std_M1
# WOqueueLenght_32threads_avg_M1    WOqueueLenght_32threads_std_M1
# WOqueueLenght_64threads_avg_M1    WOqueueLenght_64threads_std_M1
#
# WOlatencies_8threads_avg_M1       WOlatencies_8threads_std_M1
# WOlatencies_16threads_avg_M1      WOlatencies_16threads_std_M1
# WOlatencies_32threads_avg_M1      WOlatencies_32threads_std_M1
# WOlatencies_64threads_avg_M1      WOlatencies_64threads_std_M1

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a write-only workload measured in the middleware")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOthroughput_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOthroughput_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOthroughput_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOthroughput_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOthroughput_8threads_avg_M1, yerr=WOthroughput_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_16threads_avg_M1, yerr=WOthroughput_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_32threads_avg_M1, yerr=WOthroughput_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_64threads_avg_M1, yerr=WOthroughput_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_ylim(ymin=0)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ThroughputE32WOAllThreadsMiddleware1.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Queue Lenght')
plt.title("Queue Lenght of a write-only workload measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOqueueLenght_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOqueueLenght_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOqueueLenght_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOqueueLenght_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOqueueLenght_8threads_avg_M1, yerr=WOqueueLenght_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_16threads_avg_M1, yerr=WOqueueLenght_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_32threads_avg_M1, yerr=WOqueueLenght_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_64threads_avg_M1, yerr=WOqueueLenght_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("QueueLenghtE32WOAllThreadsMiddleware1.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Latencies (mse)')
plt.title("Latencies of a write-only workload measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOlatencies_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOlatencies_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOlatencies_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOlatencies_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOlatencies_8threads_avg_M1, yerr=WOlatencies_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_16threads_avg_M1, yerr=WOlatencies_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_32threads_avg_M1, yerr=WOlatencies_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_64threads_avg_M1, yerr=WOlatencies_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("LatenciesE32WOAllThreadsMiddleware1.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Service time (msec)')
plt.title("Service time measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOService_time_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOService_time_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOService_time_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOService_time_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOService_time_8threads_avg_M1, yerr=WOService_time_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOService_time_16threads_avg_M1, yerr=WOService_time_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOService_time_32threads_avg_M1, yerr=WOService_time_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOService_time_64threads_avg_M1, yerr=WOService_time_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ServiceTimeE32WOAllThreadsMiddleware1.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Waiting time (msec)')
plt.title("Waiting time measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOWaiting_time_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOWaiting_time_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOWaiting_time_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOWaiting_time_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOWaiting_time_8threads_avg_M1, yerr=WOWaiting_time_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOWaiting_time_16threads_avg_M1, yerr=WOWaiting_time_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOWaiting_time_32threads_avg_M1, yerr=WOWaiting_time_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOWaiting_time_64threads_avg_M1, yerr=WOWaiting_time_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("WaitingTimeE32WOAllThreadsMiddleware1.png", bbox_inches='tight')

# %% [markdown]
# # NOW DO THE SAME FOR MIDDLEWARE 2

# %%
MODE = 'W'
E = '3'
E_e = '3.2'
EXP = '32'

threads = 1
num_client_machines = 3
connections_per_thread = [1, 8, 16, 22, 28, 32]

clients = []

for c in connections_per_thread:
    clients.append(c*threads*num_client_machines)
clients

path_8threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/8_threads/'
path_16threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/16_threads/'
path_32threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/32_threads/'
path_64threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/64_threads/'




## This puts in the map every measure for different number of connection_per_thread and every try.

#Throughput
WOthroughput_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOthroughput_8threads_std_M2 = {1:[], 2:[], 3:[]}

WOthroughput_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOthroughput_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOthroughput_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOthroughput_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOthroughput_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOthroughput_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_8threads_avg_M2.get(n_try).append(float(avg))
            WOthroughput_8threads_std_M2.get(n_try).append(float(std))

    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_16threads_avg_M2.get(n_try).append(float(avg))
            WOthroughput_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_32threads_avg_M2.get(n_try).append(float(avg))
            WOthroughput_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOthroughput_64threads_avg_M2.get(n_try).append(float(avg))
            WOthroughput_64threads_std_M2.get(n_try).append(float(std))


            
            
# Put data of queueLenght in corresponding Maps.

#Queue Lenght
WOqueueLenght_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOqueueLenght_8threads_std_M2 = {1:[], 2:[], 3:[]}

WOqueueLenght_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOqueueLenght_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOqueueLenght_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOqueueLenght_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOqueueLenght_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOqueueLenght_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_8threads_avg_M2.get(n_try).append(float(avg))
            WOqueueLenght_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_16threads_avg_M2.get(n_try).append(float(avg))
            WOqueueLenght_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_32threads_avg_M2.get(n_try).append(float(avg))
            WOqueueLenght_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOqueueLenght_64threads_avg_M2.get(n_try).append(float(avg))
            WOqueueLenght_64threads_std_M2.get(n_try).append(float(std))

        
# Put data of Waiting Time in corresponding Maps.

#Waiting Time
WOWaitingTime_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOWaitingTime_8threads_std_M2 = {1:[], 2:[], 3:[]}

WOWaitingTime_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOWaitingTime_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOWaitingTime_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOWaitingTime_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOWaitingTime_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOWaitingTime_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_8threads_avg_M2.get(n_try).append(float(avg))
            WOWaitingTime_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_16threads_avg_M2.get(n_try).append(float(avg))
            WOWaitingTime_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_32threads_avg_M2.get(n_try).append(float(avg))
            WOWaitingTime_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOWaitingTime_64threads_avg_M2.get(n_try).append(float(avg))
            WOWaitingTime_64threads_std_M2.get(n_try).append(float(std))
            
            
# Put data of Service Time in corresponding Maps.

#Service Time

WOServiceTime_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOServiceTime_8threads_std_M2 = {1:[], 2:[], 3:[]}

WOServiceTime_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOServiceTime_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOServiceTime_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOServiceTime_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOServiceTime_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOServiceTime_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_8threads_avg_M2.get(n_try).append(float(avg))
            WOServiceTime_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_16threads_avg_M2.get(n_try).append(float(avg))
            WOServiceTime_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_32threads_avg_M2.get(n_try).append(float(avg))
            WOServiceTime_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOServiceTime_64threads_avg_M2.get(n_try).append(float(avg))
            WOServiceTime_64threads_std_M2.get(n_try).append(float(std))
            
            
#Parse Time
WOParseTime_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOParseTime_8threads_std_M2 = {1:[], 2:[], 3:[]}

WOParseTime_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOParseTime_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOParseTime_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOParseTime_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOParseTime_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOParseTime_64threads_std_M2 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_8threads_avg_M2.get(n_try).append(float(avg))
            WOParseTime_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_16threads_avg_M2.get(n_try).append(float(avg))
            WOParseTime_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_32threads_avg_M2.get(n_try).append(float(avg))
            WOParseTime_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            WOParseTime_64threads_avg_M2.get(n_try).append(float(avg))
            WOParseTime_64threads_std_M2.get(n_try).append(float(std))
            
            
print("Throughput 8 threads: "+str(len(WOthroughput_8threads_avg_M2.get(n_try))))
print("Throughput 16 threads: "+str(len(WOthroughput_16threads_avg_M2.get(n_try))))
print("Throughput 32 threads: "+str(len(WOthroughput_32threads_avg_M2.get(n_try))))
print("Throughput 64 threads: "+str(len(WOthroughput_64threads_avg_M2.get(n_try))))


print("Queue Lenght 8 threads: "+str(len(WOqueueLenght_8threads_std_M2.get(n_try))))
print("Queue Lenght 16 threads: "+str(len(WOqueueLenght_16threads_std_M2.get(n_try))))
print("Queue Lenght 32 threads: "+str(len(WOqueueLenght_32threads_std_M2.get(n_try))))
print("Queue Lenght 64 threads: "+str(len(WOqueueLenght_64threads_std_M2.get(n_try))))

print("Waiting Time Lenght 8 threads: "+str(len(WOWaitingTime_8threads_std_M2.get(n_try))))
print("Waiting Time Lenght 16 threads: "+str(len(WOWaitingTime_16threads_std_M2.get(n_try))))
print("Waiting Time Lenght 32 threads: "+str(len(WOWaitingTime_32threads_std_M2.get(n_try))))
print("Waiting Time Lenght 64 threads: "+str(len(WOWaitingTime_64threads_std_M2.get(n_try))))

print("Service Time Lenght 8 threads: "+str(len(WOServiceTime_8threads_std_M2.get(n_try))))
print("Service Time Lenght 16 threads: "+str(len(WOServiceTime_16threads_std_M2.get(n_try))))
print("Service Time Lenght 32 threads: "+str(len(WOServiceTime_32threads_std_M2.get(n_try))))
print("Service Time Lenght 64 threads: "+str(len(WOServiceTime_64threads_std_M2.get(n_try))))

print("Parse Time Lenght 8 threads: "+str(len(WOParseTime_8threads_std_M2.get(n_try))))
print("Parse Time Lenght 16 threads: "+str(len(WOParseTime_16threads_std_M2.get(n_try))))
print("Parse Time Lenght 32 threads: "+str(len(WOParseTime_32threads_std_M2.get(n_try))))
print("Parse Time Lenght 64 threads: "+str(len(WOParseTime_64threads_std_M2.get(n_try))))
# Out:
# Throughput 8 threads: 6
# Throughput 16 threads: 6
# Throughput 32 threads: 6
# Throughput 64 threads: 6
# Queue Lenght 8 threads: 6
# Queue Lenght 16 threads: 6
# Queue Lenght 32 threads: 6
# Queue Lenght 64 threads: 6
# Waiting Time Lenght 8 threads: 6
# Waiting Time Lenght 16 threads: 6
# Waiting Time Lenght 32 threads: 6
# Waiting Time Lenght 64 threads: 6
# Service Time Lenght 8 threads: 6
# Service Time Lenght 16 threads: 6
# Service Time Lenght 32 threads: 6
# Service Time Lenght 64 threads: 6
# Parse Time Lenght 8 threads: 6
# Parse Time Lenght 16 threads: 6
# Parse Time Lenght 32 threads: 6
# Parse Time Lenght 64 threads: 6

# %%
#Now calculate the following

WOlatencies_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOlatencies_8threads_std_M2 = {1:[], 2:[], 3:[]}

WOlatencies_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOlatencies_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOlatencies_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOlatencies_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOlatencies_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOlatencies_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    for i in range(0,len(WOParseTime_8threads_avg_M2.get(n_try)),1):
        WOlatencies_8threads_avg_M2.get(n_try).append(    WOParseTime_8threads_avg_M2.get(n_try)[i] + 
                                                          WOWaitingTime_8threads_avg_M2.get(n_try)[i] +
                                                          WOServiceTime_8threads_avg_M2.get(n_try)[i]
                                                     )
        WOlatencies_8threads_std_M2.get(n_try).append(    WOParseTime_8threads_std_M2.get(n_try)[i] + 
                                                          WOWaitingTime_8threads_std_M2.get(n_try)[i] +
                                                          WOServiceTime_8threads_std_M2.get(n_try)[i]
                                                     )
        
    for i in range(0,len(WOParseTime_16threads_avg_M2.get(n_try)),1):       
        WOlatencies_16threads_avg_M2.get(n_try).append(    WOParseTime_16threads_avg_M2.get(n_try)[i] + 
                                                          WOWaitingTime_16threads_avg_M2.get(n_try)[i] +
                                                          WOServiceTime_16threads_avg_M2.get(n_try)[i]
                                                     )
        
        WOlatencies_16threads_std_M2.get(n_try).append(    WOParseTime_16threads_std_M2.get(n_try)[i] + 
                                                          WOWaitingTime_16threads_std_M2.get(n_try)[i] +
                                                          WOServiceTime_16threads_std_M2.get(n_try)[i]
                                                     )
    for i in range(0,len(WOParseTime_32threads_avg_M2.get(1)),1):               
        WOlatencies_32threads_avg_M2.get(n_try).append(    WOParseTime_32threads_avg_M2.get(n_try)[i] + 
                                                          WOWaitingTime_32threads_avg_M2.get(n_try)[i] +
                                                          WOServiceTime_32threads_avg_M2.get(n_try)[i]
                                                     )
        
        WOlatencies_32threads_std_M2.get(n_try).append(    WOParseTime_32threads_std_M2.get(n_try)[i] + 
                                                          WOWaitingTime_32threads_std_M2.get(n_try)[i] +
                                                          WOServiceTime_32threads_std_M2.get(n_try)[i]
                                                     )

    for i in range(0,len(WOParseTime_64threads_avg_M2.get(1)),1):               
        WOlatencies_64threads_avg_M2.get(n_try).append(    WOParseTime_64threads_avg_M2.get(n_try)[i] + 
                                                          WOWaitingTime_64threads_avg_M2.get(n_try)[i] +
                                                          WOServiceTime_64threads_avg_M2.get(n_try)[i]
                                                     )
        
        WOlatencies_64threads_std_M2.get(n_try).append(    WOParseTime_64threads_std_M2.get(n_try)[i] + 
                                                          WOWaitingTime_64threads_std_M2.get(n_try)[i] +
                                                          WOServiceTime_64threads_std_M2.get(n_try)[i]
                                                     )
        
WOlatencies_8threads_avg_M2 = np.mean([ WOlatencies_8threads_avg_M2.get(1), WOlatencies_8threads_avg_M2.get(2), WOlatencies_8threads_avg_M2.get(3) ], axis=0)
WOlatencies_8threads_std_M2 = np.mean([ WOlatencies_8threads_std_M2.get(1), WOlatencies_8threads_std_M2.get(2), WOlatencies_8threads_std_M2.get(3) ], axis=0)

WOlatencies_16threads_avg_M2 = np.mean([ WOlatencies_16threads_avg_M2.get(1), WOlatencies_16threads_avg_M2.get(2), WOlatencies_16threads_avg_M2.get(3) ], axis=0)
WOlatencies_16threads_std_M2 = np.mean([ WOlatencies_16threads_std_M2.get(1), WOlatencies_16threads_std_M2.get(2), WOlatencies_16threads_std_M2.get(3) ], axis=0)

WOlatencies_32threads_avg_M2 = np.mean([ WOlatencies_32threads_avg_M2.get(1), WOlatencies_32threads_avg_M2.get(2), WOlatencies_32threads_avg_M2.get(3) ], axis=0)
WOlatencies_32threads_std_M2 = np.mean([ WOlatencies_32threads_std_M2.get(1), WOlatencies_32threads_std_M2.get(2), WOlatencies_32threads_std_M2.get(3) ], axis=0)

WOlatencies_64threads_avg_M2 = np.mean([ WOlatencies_64threads_avg_M2.get(1), WOlatencies_64threads_avg_M2.get(2), WOlatencies_64threads_avg_M2.get(3) ], axis=0)
WOlatencies_64threads_std_M2 = np.mean([ WOlatencies_64threads_std_M2.get(1), WOlatencies_64threads_std_M2.get(2), WOlatencies_64threads_std_M2.get(3) ], axis=0)




WOthroughput_8threads_avg_M2 = np.mean([ WOthroughput_8threads_avg_M2.get(1), WOthroughput_8threads_avg_M2.get(2), WOthroughput_8threads_avg_M2.get(3) ], axis=0)
WOthroughput_8threads_std_M2 = np.mean([ WOthroughput_8threads_std_M2.get(1), WOthroughput_8threads_std_M2.get(2), WOthroughput_8threads_std_M2.get(3) ], axis=0)

WOthroughput_16threads_avg_M2 = np.mean([ WOthroughput_16threads_avg_M2.get(1), WOthroughput_16threads_avg_M2.get(2), WOthroughput_16threads_avg_M2.get(3) ], axis=0)
WOthroughput_16threads_std_M2 = np.mean([ WOthroughput_16threads_std_M2.get(1), WOthroughput_16threads_std_M2.get(2), WOthroughput_16threads_std_M2.get(3) ], axis=0)

WOthroughput_32threads_avg_M2 = np.mean([ WOthroughput_32threads_avg_M2.get(1), WOthroughput_32threads_avg_M2.get(2), WOthroughput_32threads_avg_M2.get(3) ], axis=0)
WOthroughput_32threads_std_M2 = np.mean([ WOthroughput_32threads_std_M2.get(1), WOthroughput_32threads_std_M2.get(2), WOthroughput_32threads_std_M2.get(3) ], axis=0)

WOthroughput_64threads_avg_M2 = np.mean([ WOthroughput_64threads_avg_M2.get(1), WOthroughput_64threads_avg_M2.get(2), WOthroughput_64threads_avg_M2.get(3) ], axis=0)
WOthroughput_64threads_std_M2 = np.mean([ WOthroughput_64threads_std_M2.get(1), WOthroughput_64threads_std_M2.get(2), WOthroughput_64threads_std_M2.get(3) ], axis=0)




WOqueueLenght_8threads_avg_M2 = np.mean([ WOqueueLenght_8threads_avg_M2.get(1), WOqueueLenght_8threads_avg_M2.get(2), WOqueueLenght_8threads_avg_M2.get(3) ], axis=0)
WOqueueLenght_8threads_std_M2 = np.mean([ WOqueueLenght_8threads_std_M2.get(1), WOqueueLenght_8threads_std_M2.get(2), WOqueueLenght_8threads_std_M2.get(3) ], axis=0)

WOqueueLenght_16threads_avg_M2 = np.mean([ WOqueueLenght_16threads_avg_M2.get(1), WOqueueLenght_16threads_avg_M2.get(2), WOqueueLenght_16threads_avg_M2.get(3) ], axis=0)
WOqueueLenght_16threads_std_M2 = np.mean([ WOqueueLenght_16threads_std_M2.get(1), WOqueueLenght_16threads_std_M2.get(2), WOqueueLenght_16threads_std_M2.get(3) ], axis=0)

WOqueueLenght_32threads_avg_M2 = np.mean([ WOqueueLenght_32threads_avg_M2.get(1), WOqueueLenght_32threads_avg_M2.get(2), WOqueueLenght_32threads_avg_M2.get(3) ], axis=0)
WOqueueLenght_32threads_std_M2 = np.mean([ WOqueueLenght_32threads_std_M2.get(1), WOqueueLenght_32threads_std_M2.get(2), WOqueueLenght_32threads_std_M2.get(3) ], axis=0)

WOqueueLenght_64threads_avg_M2 = np.mean([ WOqueueLenght_64threads_avg_M2.get(1), WOqueueLenght_64threads_avg_M2.get(2), WOqueueLenght_64threads_avg_M2.get(3) ], axis=0)
WOqueueLenght_64threads_std_M2 = np.mean([ WOqueueLenght_64threads_std_M2.get(1), WOqueueLenght_64threads_std_M2.get(2), WOqueueLenght_64threads_std_M2.get(3) ], axis=0)



WOService_time_8threads_avg_M2 = np.mean([ WOServiceTime_8threads_avg_M2.get(1),WOServiceTime_8threads_avg_M2.get(2),WOServiceTime_8threads_avg_M2.get(3) ], axis=0)
WOService_time_8threads_std_M2 = np.mean([ WOServiceTime_8threads_std_M2.get(1),WOServiceTime_8threads_std_M2.get(2),WOServiceTime_8threads_std_M2.get(3) ], axis=0)

WOService_time_16threads_avg_M2 = np.mean([ WOServiceTime_16threads_avg_M2.get(1),WOServiceTime_16threads_avg_M2.get(2),WOServiceTime_16threads_avg_M2.get(3) ], axis=0)
WOService_time_16threads_std_M2 = np.mean([ WOServiceTime_16threads_std_M2.get(1),WOServiceTime_16threads_std_M2.get(2),WOServiceTime_16threads_std_M2.get(3) ], axis=0)

WOService_time_32threads_avg_M2 = np.mean([ WOServiceTime_32threads_avg_M2.get(1),WOServiceTime_32threads_avg_M2.get(2),WOServiceTime_32threads_avg_M2.get(3) ], axis=0)
WOService_time_32threads_std_M2 = np.mean([ WOServiceTime_32threads_std_M2.get(1),WOServiceTime_32threads_std_M2.get(2),WOServiceTime_32threads_std_M2.get(3) ], axis=0)

WOService_time_64threads_avg_M2 = np.mean([ WOServiceTime_64threads_avg_M2.get(1),WOServiceTime_64threads_avg_M2.get(2),WOServiceTime_64threads_avg_M2.get(3) ], axis=0)
WOService_time_64threads_std_M2 = np.mean([ WOServiceTime_64threads_std_M2.get(1),WOServiceTime_64threads_std_M2.get(2),WOServiceTime_64threads_std_M2.get(3) ], axis=0)

WOWaiting_time_8threads_avg_M2 = np.mean([ WOWaitingTime_8threads_avg_M2.get(1),WOWaitingTime_8threads_avg_M2.get(2),WOWaitingTime_8threads_avg_M2.get(3) ], axis=0)
WOWaiting_time_8threads_std_M2 = np.mean([ WOWaitingTime_8threads_std_M2.get(1),WOWaitingTime_8threads_std_M2.get(2),WOWaitingTime_8threads_std_M2.get(3) ], axis=0)

WOWaiting_time_16threads_avg_M2 = np.mean([ WOWaitingTime_16threads_avg_M2.get(1),WOWaitingTime_16threads_avg_M2.get(2),WOWaitingTime_16threads_avg_M2.get(3) ], axis=0)
WOWaiting_time_16threads_std_M2 = np.mean([ WOWaitingTime_16threads_std_M2.get(1),WOWaitingTime_16threads_std_M2.get(2),WOWaitingTime_16threads_std_M2.get(3) ], axis=0)

WOWaiting_time_32threads_avg_M2 = np.mean([ WOWaitingTime_32threads_avg_M2.get(1),WOWaitingTime_32threads_avg_M2.get(2),WOWaitingTime_32threads_avg_M2.get(3) ], axis=0)
WOWaiting_time_32threads_std_M2 = np.mean([ WOWaitingTime_32threads_std_M2.get(1),WOWaitingTime_32threads_std_M2.get(2),WOWaitingTime_32threads_std_M2.get(3) ], axis=0)

WOWaiting_time_64threads_avg_M2 = np.mean([ WOWaitingTime_64threads_avg_M2.get(1),WOWaitingTime_64threads_avg_M2.get(2),WOWaitingTime_64threads_avg_M2.get(3) ], axis=0)
WOWaiting_time_64threads_std_M2 = np.mean([ WOWaitingTime_64threads_std_M2.get(1),WOWaitingTime_64threads_std_M2.get(2),WOWaitingTime_64threads_std_M2.get(3) ], axis=0)

#TODO: calculate.

WOideal_throughput_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_throughput_8threads_avg_M2 = {1:[], 2:[], 3:[]}

WOideal_throughput_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_throughput_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOideal_throughput_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_throughput_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOideal_throughput_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_throughput_64threads_std_M2 = {1:[], 2:[], 3:[]}



WOideal_latencies_8threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_latencies_8threads_std_M2 = {1:[], 2:[], 3:[]}

WOideal_latencies_16threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_latencies_16threads_std_M2 = {1:[], 2:[], 3:[]}

WOideal_latencies_32threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_latencies_32threads_std_M2 = {1:[], 2:[], 3:[]}

WOideal_latencies_64threads_avg_M2 = {1:[], 2:[], 3:[]}
WOideal_latencies_64threads_std_M2 = {1:[], 2:[], 3:[]}

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a write-only workload measured in the middleware 2")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOthroughput_8threads_avg_M2, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOthroughput_16threads_avg_M2, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOthroughput_32threads_avg_M2, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOthroughput_64threads_avg_M2, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOthroughput_8threads_avg_M2, yerr=WOthroughput_8threads_std_M2, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_16threads_avg_M2, yerr=WOthroughput_16threads_std_M2, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_32threads_avg_M2, yerr=WOthroughput_32threads_std_M2, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_64threads_avg_M2, yerr=WOthroughput_64threads_std_M2, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ThroughputE32WOAllThreadsMiddleware2.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Queue Lenght')
plt.title("Queue Lenght of a write-only workload measured in the Middleware 2")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOqueueLenght_8threads_avg_M2, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOqueueLenght_16threads_avg_M2, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOqueueLenght_32threads_avg_M2, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOqueueLenght_64threads_avg_M2, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOqueueLenght_8threads_avg_M2, yerr=WOqueueLenght_8threads_std_M2, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_16threads_avg_M2, yerr=WOqueueLenght_16threads_std_M2, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_32threads_avg_M2, yerr=WOqueueLenght_32threads_std_M2, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_64threads_avg_M2, yerr=WOqueueLenght_64threads_std_M2, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("QueueLenghtE32WOAllThreadsMiddleware2.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Latencies (mse)')
plt.title("Latencies of a write-only workload measured in the Middleware 2")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOlatencies_8threads_avg_M2, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOlatencies_16threads_avg_M2, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOlatencies_32threads_avg_M2, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOlatencies_64threads_avg_M2, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOlatencies_8threads_avg_M2, yerr=WOlatencies_8threads_std_M2, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_16threads_avg_M2, yerr=WOlatencies_16threads_std_M2, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_32threads_avg_M2, yerr=WOlatencies_32threads_std_M2, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_64threads_avg_M2, yerr=WOlatencies_64threads_std_M2, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("LatenciesE32WOAllThreadsMiddleware2.png", bbox_inches='tight')

# %% [markdown]
# ## NOW SUM MIDDLEWARE 1 AND 2

# %%
threads = 2
num_client_machines = 3
connections_per_thread = [1, 8, 16, 22, 28, 32]

clients = []

for c in connections_per_thread:
    clients.append(c*threads*num_client_machines)
clients
# Out:
# [6, 48, 96, 132, 168, 192]

# %%
WOthroughput_8threads_avg_sum_middlewares = np.zeros(len(WOthroughput_8threads_avg_M1))
WOthroughput_8threads_std_sum_middlewares = np.zeros(len(WOthroughput_8threads_avg_M1))

WOthroughput_16threads_avg_sum_middlewares = np.zeros(len(WOthroughput_16threads_avg_M1))
WOthroughput_16threads_std_sum_middlewares = np.zeros(len(WOthroughput_16threads_avg_M1))

WOthroughput_32threads_avg_sum_middlewares = np.zeros(len(WOthroughput_32threads_avg_M1))
WOthroughput_32threads_std_sum_middlewares = np.zeros(len(WOthroughput_32threads_avg_M1))

WOthroughput_64threads_avg_sum_middlewares = np.zeros(len(WOthroughput_64threads_avg_M1))
WOthroughput_64threads_std_sum_middlewares = np.zeros(len(WOthroughput_64threads_avg_M1))

for i in range(0, len(WOthroughput_8threads_avg_M1),1):
    WOthroughput_8threads_avg_sum_middlewares[i] = WOthroughput_8threads_avg_M1[i]+WOthroughput_8threads_avg_M2[i]
    WOthroughput_8threads_std_sum_middlewares[i] = WOthroughput_8threads_std_M1[i]+WOthroughput_8threads_std_M2[i]
    
    WOthroughput_16threads_avg_sum_middlewares[i] = WOthroughput_16threads_avg_M1[i]+WOthroughput_16threads_avg_M2[i]
    WOthroughput_16threads_std_sum_middlewares[i] = WOthroughput_16threads_std_M1[i]+WOthroughput_16threads_std_M2[i]
    
    WOthroughput_32threads_avg_sum_middlewares[i] = WOthroughput_32threads_avg_M1[i]+WOthroughput_32threads_avg_M2[i]
    WOthroughput_32threads_std_sum_middlewares[i] = WOthroughput_32threads_std_M1[i]+WOthroughput_32threads_std_M2[i]
    
    WOthroughput_64threads_avg_sum_middlewares[i] = WOthroughput_64threads_avg_M1[i]+WOthroughput_64threads_avg_M2[i]
    WOthroughput_64threads_std_sum_middlewares[i] = WOthroughput_64threads_std_M1[i]+WOthroughput_64threads_std_M2[i]



WOqueueLenght_8threads_avg_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))
WOqueueLenght_8threads_std_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))

WOqueueLenght_16threads_avg_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))
WOqueueLenght_16threads_std_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))

WOqueueLenght_32threads_avg_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))
WOqueueLenght_32threads_std_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))

WOqueueLenght_64threads_avg_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))
WOqueueLenght_64threads_std_sum_middlewares = np.zeros(len(WOqueueLenght_8threads_avg_M2))

for i in range(0, len(WOthroughput_8threads_avg_M1),1):
    WOqueueLenght_8threads_avg_sum_middlewares[i] = WOqueueLenght_8threads_avg_M1[i]+WOqueueLenght_8threads_avg_M2[i]
    WOqueueLenght_8threads_std_sum_middlewares[i] = WOqueueLenght_8threads_std_M1[i]+WOqueueLenght_8threads_std_M2[i]
    
    WOqueueLenght_16threads_avg_sum_middlewares[i] = WOqueueLenght_16threads_avg_M1[i]+WOqueueLenght_16threads_avg_M2[i]
    WOqueueLenght_16threads_std_sum_middlewares[i] = WOqueueLenght_16threads_std_M1[i]+WOqueueLenght_16threads_std_M2[i]
    
    WOqueueLenght_32threads_avg_sum_middlewares[i] = WOqueueLenght_32threads_avg_M1[i]+WOqueueLenght_32threads_avg_M2[i]
    WOqueueLenght_32threads_std_sum_middlewares[i] = WOqueueLenght_32threads_std_M1[i]+WOqueueLenght_32threads_std_M2[i]
    
    WOqueueLenght_64threads_avg_sum_middlewares[i] = WOqueueLenght_64threads_avg_M1[i]+WOqueueLenght_64threads_avg_M2[i]
    WOqueueLenght_64threads_std_sum_middlewares[i] = WOqueueLenght_64threads_std_M1[i]+WOqueueLenght_64threads_std_M2[i]


    
WOlatencies_8threads_avg_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))
WOlatencies_8threads_std_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))

WOlatencies_16threads_avg_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))
WOlatencies_16threads_std_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))

WOlatencies_32threads_avg_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))
WOlatencies_32threads_std_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))

WOlatencies_64threads_avg_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))
WOlatencies_64threads_std_sum_middlewares = np.zeros(len(WOlatencies_8threads_avg_M1))

for i in range(0, len(WOthroughput_8threads_avg_M1),1):
    w1 = WOthroughput_8threads_avg_M1[i]/WOthroughput_8threads_avg_sum_middlewares[i]
    w2 = WOthroughput_8threads_avg_M2[i]/WOthroughput_8threads_avg_sum_middlewares[i]
    WOlatencies_8threads_avg_sum_middlewares[i] = WOlatencies_8threads_avg_M1[i]*w1 + WOlatencies_8threads_avg_M2[i]*w2
    WOlatencies_8threads_std_sum_middlewares[i] = WOlatencies_8threads_std_M1[i]*w1 +WOlatencies_8threads_std_M2[i]*w2

    w1 = WOthroughput_16threads_avg_M1[i]/WOthroughput_16threads_avg_sum_middlewares[i]
    w2 = WOthroughput_16threads_avg_M2[i]/WOthroughput_16threads_avg_sum_middlewares[i]
    WOlatencies_16threads_avg_sum_middlewares[i] = WOlatencies_16threads_avg_M1[i]*w1 +WOlatencies_16threads_avg_M2[i]*w2
    WOlatencies_16threads_std_sum_middlewares[i] = WOlatencies_16threads_std_M1[i]*w1 +WOlatencies_16threads_std_M2[i]*w2

    w1 = WOthroughput_32threads_avg_M1[i]/WOthroughput_32threads_avg_sum_middlewares[i]
    w2 = WOthroughput_32threads_avg_M2[i]/WOthroughput_32threads_avg_sum_middlewares[i]
    WOlatencies_32threads_avg_sum_middlewares[i] = WOlatencies_32threads_avg_M1[i]*w1 +WOlatencies_32threads_avg_M2[i]*w2
    WOlatencies_32threads_std_sum_middlewares[i] = WOlatencies_32threads_std_M1[i]*w1 +WOlatencies_32threads_std_M2[i]*w2
    
    w1 = WOthroughput_64threads_avg_M1[i]/WOthroughput_64threads_avg_sum_middlewares[i]
    w2 = WOthroughput_64threads_avg_M2[i]/WOthroughput_64threads_avg_sum_middlewares[i]
    WOlatencies_64threads_avg_sum_middlewares[i] = WOlatencies_64threads_avg_M1[i]*w1 +WOlatencies_64threads_avg_M2[i]*w2
    WOlatencies_64threads_std_sum_middlewares[i] = WOlatencies_64threads_std_M1[i]*w1 +WOlatencies_64threads_std_M2[i]*w2

    
    
num_elements = len(WOlatencies_8threads_avg_M1)
    
WOService_time_8threads_avg_sum_middlewares = np.zeros(num_elements)
WOService_time_8threads_std_sum_middlewares = np.zeros(num_elements)

WOService_time_16threads_avg_sum_middlewares = np.zeros(num_elements)
WOService_time_16threads_std_sum_middlewares = np.zeros(num_elements)

WOService_time_32threads_avg_sum_middlewares = np.zeros(num_elements)
WOService_time_32threads_std_sum_middlewares = np.zeros(num_elements)

WOService_time_64threads_avg_sum_middlewares = np.zeros(num_elements)
WOService_time_64threads_std_sum_middlewares = np.zeros(num_elements)

for i in range(0, len(WOthroughput_8threads_avg_M1),1):
    w1 = WOthroughput_8threads_avg_M1[i]/WOthroughput_8threads_avg_sum_middlewares[i]
    w2 = WOthroughput_8threads_avg_M2[i]/WOthroughput_8threads_avg_sum_middlewares[i]
    WOService_time_8threads_avg_sum_middlewares[i] = WOService_time_8threads_avg_M1[i]*w1 + WOService_time_8threads_avg_M2[i]*w2
    WOService_time_8threads_std_sum_middlewares[i] = WOService_time_8threads_std_M1[i]*w1 +WOService_time_8threads_std_M1[i]*w2

    w1 = WOthroughput_16threads_avg_M1[i]/WOthroughput_16threads_avg_sum_middlewares[i]
    w2 = WOthroughput_16threads_avg_M2[i]/WOthroughput_16threads_avg_sum_middlewares[i]
    WOService_time_16threads_avg_sum_middlewares[i] = WOService_time_16threads_avg_M1[i]*w1 +WOService_time_16threads_avg_M2[i]*w2
    WOService_time_16threads_std_sum_middlewares[i] = WOService_time_16threads_std_M1[i]*w1 +WOService_time_16threads_std_M2[i]*w2

    w1 = WOthroughput_32threads_avg_M1[i]/WOthroughput_32threads_avg_sum_middlewares[i]
    w2 = WOthroughput_32threads_avg_M2[i]/WOthroughput_32threads_avg_sum_middlewares[i]
    WOService_time_32threads_avg_sum_middlewares[i] = WOService_time_32threads_avg_M1[i]*w1 +WOService_time_32threads_avg_M2[i]*w2
    WOService_time_32threads_std_sum_middlewares[i] = WOService_time_32threads_std_M1[i]*w1 +WOService_time_32threads_std_M2[i]*w2
    
    w1 = WOthroughput_64threads_avg_M1[i]/WOthroughput_64threads_avg_sum_middlewares[i]
    w2 = WOthroughput_64threads_avg_M2[i]/WOthroughput_64threads_avg_sum_middlewares[i]
    WOService_time_64threads_avg_sum_middlewares[i] = WOService_time_64threads_avg_M1[i]*w1 +WOService_time_64threads_avg_M2[i]*w2
    WOService_time_64threads_std_sum_middlewares[i] = WOService_time_64threads_std_M1[i]*w1 +WOService_time_64threads_std_M2[i]*w2


    
WOWaiting_time_8threads_avg_sum_middlewares = np.zeros(num_elements)
WOWaiting_time_8threads_std_sum_middlewares = np.zeros(num_elements)

WOWaiting_time_16threads_avg_sum_middlewares = np.zeros(num_elements)
WOWaiting_time_16threads_std_sum_middlewares = np.zeros(num_elements)

WOWaiting_time_32threads_avg_sum_middlewares = np.zeros(num_elements)
WOWaiting_time_32threads_std_sum_middlewares = np.zeros(num_elements)

WOWaiting_time_64threads_avg_sum_middlewares = np.zeros(num_elements)
WOWaiting_time_64threads_std_sum_middlewares = np.zeros(num_elements)

for i in range(0, len(WOthroughput_8threads_avg_M1),1):
    w1 = WOthroughput_8threads_avg_M1[i]/WOthroughput_8threads_avg_sum_middlewares[i]
    w2 = WOthroughput_8threads_avg_M2[i]/WOthroughput_8threads_avg_sum_middlewares[i]
    WOWaiting_time_8threads_avg_sum_middlewares[i] = WOWaiting_time_8threads_avg_M1[i]*w1 + WOWaiting_time_8threads_avg_M2[i]*w2
    WOWaiting_time_8threads_std_sum_middlewares[i] = WOWaiting_time_8threads_std_M1[i]*w1 +WOWaiting_time_8threads_std_M2[i]*w2

    w1 = WOthroughput_16threads_avg_M1[i]/WOthroughput_16threads_avg_sum_middlewares[i]
    w2 = WOthroughput_16threads_avg_M2[i]/WOthroughput_16threads_avg_sum_middlewares[i]
    WOWaiting_time_16threads_avg_sum_middlewares[i] = WOWaiting_time_16threads_avg_M1[i]*w1 +WOWaiting_time_16threads_avg_M2[i]*w2
    WOWaiting_time_16threads_std_sum_middlewares[i] = WOWaiting_time_16threads_std_M1[i]*w1 +WOWaiting_time_16threads_std_M2[i]*w2

    w1 = WOthroughput_32threads_avg_M1[i]/WOthroughput_32threads_avg_sum_middlewares[i]
    w2 = WOthroughput_32threads_avg_M2[i]/WOthroughput_32threads_avg_sum_middlewares[i]
    WOWaiting_time_32threads_avg_sum_middlewares[i] = WOWaiting_time_32threads_avg_M1[i]*w1 +WOWaiting_time_32threads_avg_M2[i]*w2
    WOWaiting_time_32threads_std_sum_middlewares[i] = WOWaiting_time_32threads_std_M1[i]*w1 +WOWaiting_time_32threads_std_M2[i]*w2
    
    w1 = WOthroughput_64threads_avg_M1[i]/WOthroughput_64threads_avg_sum_middlewares[i]
    w2 = WOthroughput_64threads_avg_M2[i]/WOthroughput_64threads_avg_sum_middlewares[i]
    WOWaiting_time_64threads_avg_sum_middlewares[i] = WOWaiting_time_64threads_avg_M1[i]*w1 +WOWaiting_time_64threads_avg_M2[i]*w2
    WOWaiting_time_64threads_std_sum_middlewares[i] = WOWaiting_time_64threads_std_M1[i]*w1 +WOWaiting_time_64threads_std_M2[i]*w2

# %%
ping_latencies = 1.3
WOideal_throughput_8threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_throughput_16threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_throughput_32threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_throughput_64threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))

WOideal_throughput_8threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_throughput_16threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_throughput_32threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_throughput_64threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))

WOideal_latencies_8threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_latencies_16threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_latencies_32threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_latencies_64threads_avg_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))

WOideal_latencies_8threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_latencies_16threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_latencies_32threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))
WOideal_latencies_64threads_std_sum_middleware = np.zeros((len(WOthroughput_8threads_avg_M1)))

for i in range(0,len(WOthroughput_8threads_avg_M1),1):
    WOideal_throughput_8threads_avg_sum_middleware[i] = (1/((WOlatencies_8threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    WOideal_throughput_16threads_avg_sum_middleware[i] = (1/((WOlatencies_16threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    WOideal_throughput_32threads_avg_sum_middleware[i] = (1/((WOlatencies_32threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    WOideal_throughput_64threads_avg_sum_middleware[i] = (1/((WOlatencies_64threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])

    WOideal_throughput_8threads_std_sum_middleware[i] = (1/((WOlatencies_8threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    WOideal_throughput_16threads_std_sum_middleware[i] = (1/((WOlatencies_16threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    WOideal_throughput_32threads_std_sum_middleware[i] = (1/((WOlatencies_32threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    WOideal_throughput_64threads_std_sum_middleware[i] = (1/((WOlatencies_64threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])

    
    WOideal_latencies_8threads_avg_sum_middleware[i] = 1000*(1/WOthroughput_8threads_avg_sum_middlewares[i])*(clients[i])
    WOideal_latencies_16threads_avg_sum_middleware[i] = 1000*(1/WOthroughput_16threads_avg_sum_middlewares[i])*(clients[i])
    WOideal_latencies_32threads_avg_sum_middleware[i] = 1000*(1/WOthroughput_32threads_avg_sum_middlewares[i])*(clients[i])
    WOideal_latencies_64threads_avg_sum_middleware[i] = 1000*(1/WOthroughput_64threads_avg_sum_middlewares[i])*(clients[i])
   

    WOideal_latencies_8threads_std_sum_middleware[i] = 1000*(1/WOthroughput_8threads_std_sum_middlewares[i])*(clients[i])
    WOideal_latencies_16threads_std_sum_middleware[i] = 1000*(1/WOthroughput_16threads_std_sum_middlewares[i])*(clients[i])
    WOideal_latencies_32threads_std_sum_middleware[i] = 1000*(1/WOthroughput_32threads_std_sum_middlewares[i])*(clients[i])
    WOideal_latencies_64threads_std_sum_middleware[i] = 1000*(1/WOthroughput_64threads_std_sum_middlewares[i])*(clients[i])

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a write-only workload measured in the middleware")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOthroughput_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_8T, = plt.plot(clients, WOideal_throughput_8threads_avg_sum_middleware, color='blue', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

line_16T, = plt.plot(clients, WOthroughput_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_16T, = plt.plot(clients, WOideal_throughput_16threads_avg_sum_middleware, color='red', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

line_32T, = plt.plot(clients, WOthroughput_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_32T, = plt.plot(clients, WOideal_throughput_32threads_avg_sum_middleware, color='green', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

line_64T, = plt.plot(clients, WOthroughput_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_64T, = plt.plot(clients, WOideal_throughput_64threads_avg_sum_middleware, color='yellow', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOthroughput_8threads_avg_sum_middlewares, yerr=WOthroughput_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_16threads_avg_sum_middlewares, yerr=WOthroughput_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_32threads_avg_sum_middlewares, yerr=WOthroughput_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_64threads_avg_sum_middlewares, yerr=WOthroughput_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("IdealThroughputE31WOAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Waiting time (msec)')
plt.title("Waiting time measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOWaiting_time_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOWaiting_time_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOWaiting_time_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOWaiting_time_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOWaiting_time_8threads_avg_sum_middlewares, yerr=WOWaiting_time_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOWaiting_time_16threads_avg_sum_middlewares, yerr=WOWaiting_time_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOWaiting_time_32threads_avg_sum_middlewares, yerr=WOWaiting_time_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOWaiting_time_64threads_avg_sum_middlewares, yerr=WOWaiting_time_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)
ax_lst.set_ylim(ymax=20)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("WaitingTimeE32WOAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Service time (msec)')
plt.title("Service time measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOService_time_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOService_time_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOService_time_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOService_time_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,WOService_time_8threads_avg_sum_middlewares, yerr=WOService_time_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOService_time_16threads_avg_sum_middlewares, yerr=WOService_time_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOService_time_32threads_avg_sum_middlewares, yerr=WOService_time_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOService_time_64threads_avg_sum_middlewares, yerr=WOService_time_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)
ax_lst.set_ylim(ymax=20)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ServiceTimeE32WOAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a write-only workload measured in both middlewares ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOthroughput_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOthroughput_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOthroughput_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOthroughput_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)


ax_lst.errorbar(clients,WOthroughput_8threads_avg_sum_middlewares, yerr=WOthroughput_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_16threads_avg_sum_middlewares, yerr=WOthroughput_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_32threads_avg_sum_middlewares, yerr=WOthroughput_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOthroughput_64threads_avg_sum_middlewares, yerr=WOthroughput_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ThroughputE32WOAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
import csv

with open('../Write_Only_Throughput_DataExp32.csv', 'wb') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(WOthroughput_8threads_avg_sum_middlewares)
    writer.writerow(WOthroughput_8threads_std_sum_middlewares)
    
    writer.writerow(WOthroughput_16threads_avg_sum_middlewares)
    writer.writerow(WOthroughput_16threads_std_sum_middlewares)
    
    writer.writerow(WOthroughput_32threads_avg_sum_middlewares)
    writer.writerow(WOthroughput_32threads_std_sum_middlewares)
    
    writer.writerow(WOthroughput_64threads_avg_sum_middlewares)
    writer.writerow(WOthroughput_64threads_std_sum_middlewares)

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Queue Lenght')
plt.title("Queue Lenght of a write-only workload measured in both middlewares")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOqueueLenght_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOqueueLenght_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOqueueLenght_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOqueueLenght_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)



ax_lst.errorbar(clients,WOqueueLenght_8threads_avg_sum_middlewares, yerr=WOqueueLenght_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_16threads_avg_sum_middlewares, yerr=WOqueueLenght_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_32threads_avg_sum_middlewares, yerr=WOqueueLenght_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOqueueLenght_64threads_avg_sum_middlewares, yerr=WOqueueLenght_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("QueueLenghtE32WOAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
import csv

with open('../Write_Only_QueueLenght_DataExp32.csv', 'wb') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(WOqueueLenght_8threads_avg_sum_middlewares)
    writer.writerow(WOqueueLenght_8threads_std_sum_middlewares)
    
    writer.writerow(WOqueueLenght_16threads_avg_sum_middlewares)
    writer.writerow(WOqueueLenght_16threads_std_sum_middlewares)
    
    writer.writerow(WOqueueLenght_32threads_avg_sum_middlewares)
    writer.writerow(WOqueueLenght_32threads_std_sum_middlewares)
    
    writer.writerow(WOqueueLenght_64threads_avg_sum_middlewares)
    writer.writerow(WOqueueLenght_64threads_std_sum_middlewares)

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Latencies (mse)')
plt.title("Latencies of a write-only workload measured in both middlewares")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, WOlatencies_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, WOlatencies_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, WOlatencies_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, WOlatencies_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)


ax_lst.errorbar(clients,WOlatencies_8threads_avg_sum_middlewares, yerr=WOlatencies_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_16threads_avg_sum_middlewares, yerr=WOlatencies_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_32threads_avg_sum_middlewares, yerr=WOlatencies_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,WOlatencies_64threads_avg_sum_middlewares, yerr=WOlatencies_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("LatenciesE32WOAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
import csv

with open('../Write_Only_Latencies_DataExp32.csv', 'wb') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(WOlatencies_8threads_avg_sum_middlewares)
    writer.writerow(WOlatencies_8threads_std_sum_middlewares)
    
    writer.writerow(WOlatencies_16threads_avg_sum_middlewares)
    writer.writerow(WOlatencies_16threads_std_sum_middlewares)
    
    writer.writerow(WOlatencies_32threads_avg_sum_middlewares)
    writer.writerow(WOlatencies_32threads_std_sum_middlewares)
    
    writer.writerow(WOlatencies_64threads_avg_sum_middlewares)
    writer.writerow(WOlatencies_64threads_std_sum_middlewares)

# %%
print(WOthroughput_64threads_avg_sum_middlewares)
print(WOService_time_64threads_avg_sum_middlewares)
# Out:
# [ 2948.27666667 10172.20666667 11311.39666667 13800.9
#  13841.06       14567.11666667]
# [1.20323543 3.77885063 5.8000347  7.42160119 9.21631714 8.47294626]

# %% [markdown]
# ### For READ ONLY

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.ticker import NullFormatter  , ScalarFormatter
import matplotlib.axes as ax
import numpy as np
import statistics as st

# %%
MODE = 'R'
E = '3'
E_e = '3.2'
EXP = '32'

threads = 1
num_client_machines = 3
#clients=(1 8 16 22 28 32 40 50 60 100 300 500)
connections_per_thread = [1, 8, 16, 22, 28, 32]

clients = []

for c in connections_per_thread:
    clients.append(c*threads*num_client_machines)
clients

path_8threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/8_threads/'
path_16threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/16_threads/'
path_32threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/32_threads/'
path_64threads_M1 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware1/64_threads/'

# %%
# This puts in the map every measure for different number of connection_per_thread and every try.

#Throughput
ROthroughput_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROthroughput_8threads_std_M1 = {1:[], 2:[], 3:[]}

ROthroughput_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROthroughput_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROthroughput_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROthroughput_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROthroughput_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROthroughput_64threads_std_M1 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_8threads_avg_M1.get(n_try).append(float(avg))
            ROthroughput_8threads_std_M1.get(n_try).append(float(std))

    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_16threads_avg_M1.get(n_try).append(float(avg))
            ROthroughput_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_32threads_avg_M1.get(n_try).append(float(avg))
            ROthroughput_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_64threads_avg_M1.get(n_try).append(float(avg))
            ROthroughput_64threads_std_M1.get(n_try).append(float(std))

# Put data of queueLenght in corresponding Maps.

#Queue Lenght
ROqueueLenght_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROqueueLenght_8threads_std_M1 = {1:[], 2:[], 3:[]}

ROqueueLenght_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROqueueLenght_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROqueueLenght_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROqueueLenght_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROqueueLenght_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROqueueLenght_64threads_std_M1 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_8threads_avg_M1.get(n_try).append(float(avg))
            ROqueueLenght_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_16threads_avg_M1.get(n_try).append(float(avg))
            ROqueueLenght_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_32threads_avg_M1.get(n_try).append(float(avg))
            ROqueueLenght_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_64threads_avg_M1.get(n_try).append(float(avg))
            ROqueueLenght_64threads_std_M1.get(n_try).append(float(std))

        
# Put data of Waiting Time in corresponding Maps.

#Waiting Time
ROWaitingTime_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROWaitingTime_8threads_std_M1 = {1:[], 2:[], 3:[]}

ROWaitingTime_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROWaitingTime_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROWaitingTime_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROWaitingTime_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROWaitingTime_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROWaitingTime_64threads_std_M1 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_8threads_avg_M1.get(n_try).append(float(avg))
            ROWaitingTime_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_16threads_avg_M1.get(n_try).append(float(avg))
            ROWaitingTime_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_32threads_avg_M1.get(n_try).append(float(avg))
            ROWaitingTime_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_64threads_avg_M1.get(n_try).append(float(avg))
            ROWaitingTime_64threads_std_M1.get(n_try).append(float(std))
            
# Put data of Service Time in corresponding Maps.

#Service Time

ROServiceTime_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROServiceTime_8threads_std_M1 = {1:[], 2:[], 3:[]}

ROServiceTime_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROServiceTime_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROServiceTime_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROServiceTime_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROServiceTime_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROServiceTime_64threads_std_M1 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_8threads_avg_M1.get(n_try).append(float(avg))
            ROServiceTime_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_16threads_avg_M1.get(n_try).append(float(avg))
            ROServiceTime_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_32threads_avg_M1.get(n_try).append(float(avg))
            ROServiceTime_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_64threads_avg_M1.get(n_try).append(float(avg))
            ROServiceTime_64threads_std_M1.get(n_try).append(float(std))
            
            
#Parse Time
ROParseTime_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROParseTime_8threads_std_M1 = {1:[], 2:[], 3:[]}

ROParseTime_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROParseTime_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROParseTime_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROParseTime_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROParseTime_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROParseTime_64threads_std_M1 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M1)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd1_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_8threads_avg_M1.get(n_try).append(float(avg))
            ROParseTime_8threads_std_M1.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_16threads_avg_M1.get(n_try).append(float(avg))
            ROParseTime_16threads_std_M1.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_32threads_avg_M1.get(n_try).append(float(avg))
            ROParseTime_32threads_std_M1.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_64threads_avg_M1.get(n_try).append(float(avg))
            ROParseTime_64threads_std_M1.get(n_try).append(float(std))

            

#Now calculate the following

ROlatencies_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROlatencies_8threads_std_M1 = {1:[], 2:[], 3:[]}

ROlatencies_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROlatencies_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROlatencies_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROlatencies_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROlatencies_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROlatencies_64threads_std_M1 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    for i in range(0,len(ROParseTime_8threads_avg_M1.get(n_try)),1):
        ROlatencies_8threads_avg_M1.get(n_try).append(    ROParseTime_8threads_avg_M1.get(n_try)[i] + 
                                                          ROWaitingTime_8threads_avg_M1.get(n_try)[i] +
                                                          ROServiceTime_8threads_avg_M1.get(n_try)[i]
                                                     )
        ROlatencies_8threads_std_M1.get(n_try).append(    ROParseTime_8threads_std_M1.get(n_try)[i] + 
                                                          ROWaitingTime_8threads_std_M1.get(n_try)[i] +
                                                          ROServiceTime_8threads_std_M1.get(n_try)[i]
                                                     )
    for i in range(0,len(ROParseTime_16threads_avg_M1.get(n_try)),1):       
        ROlatencies_16threads_avg_M1.get(n_try).append(   ROParseTime_16threads_avg_M1.get(n_try)[i] + 
                                                          ROWaitingTime_16threads_avg_M1.get(n_try)[i] +
                                                          ROServiceTime_16threads_avg_M1.get(n_try)[i]
                                                     )
        
        ROlatencies_16threads_std_M1.get(n_try).append(   ROParseTime_16threads_std_M1.get(n_try)[i] + 
                                                          ROWaitingTime_16threads_std_M1.get(n_try)[i] +
                                                          ROServiceTime_16threads_std_M1.get(n_try)[i]
                                                     )
    for i in range(0,len(ROParseTime_32threads_avg_M1.get(1)),1):               
        ROlatencies_32threads_avg_M1.get(n_try).append(   ROParseTime_32threads_avg_M1.get(n_try)[i] + 
                                                          ROWaitingTime_32threads_avg_M1.get(n_try)[i] +
                                                          ROServiceTime_32threads_avg_M1.get(n_try)[i]
                                                     )
        
        ROlatencies_32threads_std_M1.get(n_try).append(   ROParseTime_32threads_std_M1.get(n_try)[i] + 
                                                          ROWaitingTime_32threads_std_M1.get(n_try)[i] +
                                                          ROServiceTime_32threads_std_M1.get(n_try)[i]
                                                     )

    for i in range(0,len(ROParseTime_64threads_avg_M1.get(1)),1):               
        ROlatencies_64threads_avg_M1.get(n_try).append(   ROParseTime_64threads_avg_M1.get(n_try)[i] + 
                                                          ROWaitingTime_64threads_avg_M1.get(n_try)[i] +
                                                          ROServiceTime_64threads_avg_M1.get(n_try)[i]
                                                     )
        
        ROlatencies_64threads_std_M1.get(n_try).append(   ROParseTime_64threads_std_M1.get(n_try)[i] + 
                                                          ROWaitingTime_64threads_std_M1.get(n_try)[i] +
                                                          ROServiceTime_64threads_std_M1.get(n_try)[i]
                                                     )
        
        
ROlatencies_8threads_avg_M1 = np.mean([ ROlatencies_8threads_avg_M1.get(1), ROlatencies_8threads_avg_M1.get(2), ROlatencies_8threads_avg_M1.get(3) ], axis=0)
ROlatencies_8threads_std_M1 = np.mean([ ROlatencies_8threads_std_M1.get(1), ROlatencies_8threads_std_M1.get(2), ROlatencies_8threads_std_M1.get(3) ], axis=0)

ROlatencies_16threads_avg_M1 = np.mean([ ROlatencies_16threads_avg_M1.get(1), ROlatencies_16threads_avg_M1.get(2), ROlatencies_16threads_avg_M1.get(3) ], axis=0)
ROlatencies_16threads_std_M1 = np.mean([ ROlatencies_16threads_std_M1.get(1), ROlatencies_16threads_std_M1.get(2), ROlatencies_16threads_std_M1.get(3) ], axis=0)

ROlatencies_32threads_avg_M1 = np.mean([ ROlatencies_32threads_avg_M1.get(1), ROlatencies_32threads_avg_M1.get(2), ROlatencies_32threads_avg_M1.get(3) ], axis=0)
ROlatencies_32threads_std_M1 = np.mean([ ROlatencies_32threads_std_M1.get(1), ROlatencies_32threads_std_M1.get(2), ROlatencies_32threads_std_M1.get(3) ], axis=0)

ROlatencies_64threads_avg_M1 = np.mean([ ROlatencies_64threads_avg_M1.get(1), ROlatencies_64threads_avg_M1.get(2), ROlatencies_64threads_avg_M1.get(3) ], axis=0)
ROlatencies_64threads_std_M1 = np.mean([ ROlatencies_64threads_std_M1.get(1), ROlatencies_64threads_std_M1.get(2), ROlatencies_64threads_std_M1.get(3) ], axis=0)


ROthroughput_8threads_avg_M1 = np.mean([ ROthroughput_8threads_avg_M1.get(1), ROthroughput_8threads_avg_M1.get(2), ROthroughput_8threads_avg_M1.get(3) ], axis=0)
ROthroughput_8threads_std_M1 = np.mean([ ROthroughput_8threads_std_M1.get(1), ROthroughput_8threads_std_M1.get(2), ROthroughput_8threads_std_M1.get(3) ], axis=0)

ROthroughput_16threads_avg_M1 = np.mean([ ROthroughput_16threads_avg_M1.get(1), ROthroughput_16threads_avg_M1.get(2), ROthroughput_16threads_avg_M1.get(3) ], axis=0)
ROthroughput_16threads_std_M1 = np.mean([ ROthroughput_16threads_std_M1.get(1), ROthroughput_16threads_std_M1.get(2), ROthroughput_16threads_std_M1.get(3) ], axis=0)

ROthroughput_32threads_avg_M1 = np.mean([ ROthroughput_32threads_avg_M1.get(1), ROthroughput_32threads_avg_M1.get(2), ROthroughput_32threads_avg_M1.get(3) ], axis=0)
ROthroughput_32threads_std_M1 = np.mean([ ROthroughput_32threads_std_M1.get(1), ROthroughput_32threads_std_M1.get(2), ROthroughput_32threads_std_M1.get(3) ], axis=0)

ROthroughput_64threads_avg_M1 = np.mean([ ROthroughput_64threads_avg_M1.get(1), ROthroughput_64threads_avg_M1.get(2), ROthroughput_64threads_avg_M1.get(3) ], axis=0)
ROthroughput_64threads_std_M1 = np.mean([ ROthroughput_64threads_std_M1.get(1), ROthroughput_64threads_std_M1.get(2), ROthroughput_64threads_std_M1.get(3) ], axis=0)

ROqueueLenght_8threads_avg_M1 = np.mean([ ROqueueLenght_8threads_avg_M1.get(1), ROqueueLenght_8threads_avg_M1.get(2), ROqueueLenght_8threads_avg_M1.get(3) ], axis=0)
ROqueueLenght_8threads_std_M1 = np.mean([ ROqueueLenght_8threads_std_M1.get(1), ROqueueLenght_8threads_std_M1.get(2), ROqueueLenght_8threads_std_M1.get(3) ], axis=0)

ROqueueLenght_16threads_avg_M1 = np.mean([ ROqueueLenght_16threads_avg_M1.get(1), ROqueueLenght_16threads_avg_M1.get(2), ROqueueLenght_16threads_avg_M1.get(3) ], axis=0)
ROqueueLenght_16threads_std_M1 = np.mean([ ROqueueLenght_16threads_std_M1.get(1), ROqueueLenght_16threads_std_M1.get(2), ROqueueLenght_16threads_std_M1.get(3) ], axis=0)

ROqueueLenght_32threads_avg_M1 = np.mean([ ROqueueLenght_32threads_avg_M1.get(1), ROqueueLenght_32threads_avg_M1.get(2), ROqueueLenght_32threads_avg_M1.get(3) ], axis=0)
ROqueueLenght_32threads_std_M1 = np.mean([ ROqueueLenght_32threads_std_M1.get(1), ROqueueLenght_32threads_std_M1.get(2), ROqueueLenght_32threads_std_M1.get(3) ], axis=0)

ROqueueLenght_64threads_avg_M1 = np.mean([ ROqueueLenght_64threads_avg_M1.get(1), ROqueueLenght_64threads_avg_M1.get(2), ROqueueLenght_64threads_avg_M1.get(3) ], axis=0)
ROqueueLenght_64threads_std_M1 = np.mean([ ROqueueLenght_64threads_std_M1.get(1), ROqueueLenght_64threads_std_M1.get(2), ROqueueLenght_64threads_std_M1.get(3) ], axis=0)


ROService_time_8threads_avg_M1 = np.mean([ ROServiceTime_8threads_avg_M1.get(1),ROServiceTime_8threads_avg_M1.get(2),ROServiceTime_8threads_avg_M1.get(3) ], axis=0)
ROService_time_8threads_std_M1 = np.mean([ ROServiceTime_8threads_std_M1.get(1),ROServiceTime_8threads_std_M1.get(2),ROServiceTime_8threads_std_M1.get(3) ], axis=0)

ROService_time_16threads_avg_M1 = np.mean([ ROServiceTime_16threads_avg_M1.get(1),ROServiceTime_16threads_avg_M1.get(2),ROServiceTime_16threads_avg_M1.get(3) ], axis=0)
ROService_time_16threads_std_M1 = np.mean([ ROServiceTime_16threads_std_M1.get(1),ROServiceTime_16threads_std_M1.get(2),ROServiceTime_16threads_std_M1.get(3) ], axis=0)

ROService_time_32threads_avg_M1 = np.mean([ ROServiceTime_32threads_avg_M1.get(1),ROServiceTime_32threads_avg_M1.get(2),ROServiceTime_32threads_avg_M1.get(3) ], axis=0)
ROService_time_32threads_std_M1 = np.mean([ ROServiceTime_32threads_std_M1.get(1),ROServiceTime_32threads_std_M1.get(2),ROServiceTime_32threads_std_M1.get(3) ], axis=0)

ROService_time_64threads_avg_M1 = np.mean([ ROServiceTime_64threads_avg_M1.get(1),ROServiceTime_64threads_avg_M1.get(2),ROServiceTime_64threads_avg_M1.get(3) ], axis=0)
ROService_time_64threads_std_M1 = np.mean([ ROServiceTime_64threads_std_M1.get(1),ROServiceTime_64threads_std_M1.get(2),ROServiceTime_64threads_std_M1.get(3) ], axis=0)

ROWaiting_time_8threads_avg_M1 = np.mean([ ROWaitingTime_8threads_avg_M1.get(1),ROWaitingTime_8threads_avg_M1.get(2),ROWaitingTime_8threads_avg_M1.get(3) ], axis=0)
ROWaiting_time_8threads_std_M1 = np.mean([ ROWaitingTime_8threads_std_M1.get(1),ROWaitingTime_8threads_std_M1.get(2),ROWaitingTime_8threads_std_M1.get(3) ], axis=0)

ROWaiting_time_16threads_avg_M1 = np.mean([ ROWaitingTime_16threads_avg_M1.get(1),ROWaitingTime_16threads_avg_M1.get(2),ROWaitingTime_16threads_avg_M1.get(3) ], axis=0)
ROWaiting_time_16threads_std_M1 = np.mean([ ROWaitingTime_16threads_std_M1.get(1),ROWaitingTime_16threads_std_M1.get(2),ROWaitingTime_16threads_std_M1.get(3) ], axis=0)

ROWaiting_time_32threads_avg_M1 = np.mean([ ROWaitingTime_32threads_avg_M1.get(1),ROWaitingTime_32threads_avg_M1.get(2),ROWaitingTime_32threads_avg_M1.get(3) ], axis=0)
ROWaiting_time_32threads_std_M1 = np.mean([ ROWaitingTime_32threads_std_M1.get(1),ROWaitingTime_32threads_std_M1.get(2),ROWaitingTime_32threads_std_M1.get(3) ], axis=0)

ROWaiting_time_64threads_avg_M1 = np.mean([ ROWaitingTime_64threads_avg_M1.get(1),ROWaitingTime_64threads_avg_M1.get(2),ROWaitingTime_64threads_avg_M1.get(3) ], axis=0)
ROWaiting_time_64threads_std_M1 = np.mean([ ROWaitingTime_64threads_std_M1.get(1),ROWaitingTime_64threads_std_M1.get(2),ROWaitingTime_64threads_std_M1.get(3) ], axis=0)

# %%
#To calculate.

ROideal_throughput_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_throughput_8threads_avg_M1 = {1:[], 2:[], 3:[]}

ROideal_throughput_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_throughput_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROideal_throughput_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_throughput_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROideal_throughput_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_throughput_64threads_std_M1 = {1:[], 2:[], 3:[]}



ROideal_latencies_8threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_latencies_8threads_std_M1 = {1:[], 2:[], 3:[]}

ROideal_latencies_16threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_latencies_16threads_std_M1 = {1:[], 2:[], 3:[]}

ROideal_latencies_32threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_latencies_32threads_std_M1 = {1:[], 2:[], 3:[]}

ROideal_latencies_64threads_avg_M1 = {1:[], 2:[], 3:[]}
ROideal_latencies_64threads_std_M1 = {1:[], 2:[], 3:[]}

# %% [markdown]
# ROthroughput_8threads_avg_M1       ROthroughput_8threads_std_M1
# ROthroughput_16threads_avg_M1      ROthroughput_16threads_std_M1
# ROthroughput_32threads_avg_M1      ROthroughput_32threads_std_M1
# ROthroughput_64threads_avg_M1      ROthroughput_64threads_std_M1
#
#
# ROqueueLenght_8threads_avg_M1     ROqueueLenght_8threads_std_M1
# ROqueueLenght_16threads_avg_M1    ROqueueLenght_16threads_std_M1
# ROqueueLenght_32threads_avg_M1    ROqueueLenght_32threads_std_M1
# ROqueueLenght_64threads_avg_M1    ROqueueLenght_64threads_std_M1
#
# ROlatencies_8threads_avg_M1       ROlatencies_8threads_std_M1
# ROlatencies_16threads_avg_M1      ROlatencies_16threads_std_M1
# ROlatencies_32threads_avg_M1      ROlatencies_32threads_std_M1
# ROlatencies_64threads_avg_M1      ROlatencies_64threads_std_M1

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a read-only workload measured in the Middleware 1")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROthroughput_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROthroughput_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROthroughput_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROthroughput_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROthroughput_8threads_avg_M1, yerr=ROthroughput_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_16threads_avg_M1, yerr=ROthroughput_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_32threads_avg_M1, yerr=ROthroughput_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_64threads_avg_M1, yerr=ROthroughput_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ThroughputE32ROAllThreadsMiddleware1.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Queue Lenght')
plt.title("Queue Lenght of a read-only workload measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROqueueLenght_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROqueueLenght_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROqueueLenght_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROqueueLenght_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROqueueLenght_8threads_avg_M1, yerr=ROqueueLenght_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_16threads_avg_M1, yerr=ROqueueLenght_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_32threads_avg_M1, yerr=ROqueueLenght_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_64threads_avg_M1, yerr=ROqueueLenght_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("QueueLenghtE32ROAllThreadsMiddleware1.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Latencies (mse)')
plt.title("Latencies of a read-only workload measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROlatencies_8threads_avg_M1, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROlatencies_16threads_avg_M1, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROlatencies_32threads_avg_M1, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROlatencies_64threads_avg_M1, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROlatencies_8threads_avg_M1, yerr=ROlatencies_8threads_std_M1, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_16threads_avg_M1, yerr=ROlatencies_16threads_std_M1, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_32threads_avg_M1, yerr=ROlatencies_32threads_std_M1, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_64threads_avg_M1, yerr=ROlatencies_64threads_std_M1, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("LatenciesE32ROAllThreadsMiddleware1.png", bbox_inches='tight')

# %% [markdown]
# ## DO SAME FOR MIDDLEWARE 2

# %%
MODE = 'R'
E = '3'
E_e = '3.2'
EXP = '32'

threads = 1
num_client_machines = 3
connections_per_thread = [1, 8, 16, 22, 28, 32]

clients = []

for c in connections_per_thread:
    clients.append(c*threads*num_client_machines)
clients

path_8threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/8_threads/'
path_16threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/16_threads/'
path_32threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/32_threads/'
path_64threads_M2 = '/home/fla/Desktop/asl-fall18-project/Experiments/Exp_'+str(E)+'/'+str(E_e)+'/'+str(MODE)+'_only/Middleware2/64_threads/'



## This puts in the map every measure for different number of connection_per_thread and every try.

#Throughput
ROthroughput_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROthroughput_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROthroughput_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROthroughput_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROthroughput_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROthroughput_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROthroughput_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROthroughput_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'THROUGHPUT_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_8threads_avg_M2.get(n_try).append(float(avg))
            ROthroughput_8threads_std_M2.get(n_try).append(float(std))

    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_16threads_avg_M2.get(n_try).append(float(avg))
            ROthroughput_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_32threads_avg_M2.get(n_try).append(float(avg))
            ROthroughput_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROthroughput_64threads_avg_M2.get(n_try).append(float(avg))
            ROthroughput_64threads_std_M2.get(n_try).append(float(std))

# Put data of queueLenght in corresponding Maps.

#Queue Lenght
ROqueueLenght_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROqueueLenght_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROqueueLenght_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROqueueLenght_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROqueueLenght_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROqueueLenght_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROqueueLenght_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROqueueLenght_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'QueueLength_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_8threads_avg_M2.get(n_try).append(float(avg))
            ROqueueLenght_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_16threads_avg_M2.get(n_try).append(float(avg))
            ROqueueLenght_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_32threads_avg_M2.get(n_try).append(float(avg))
            ROqueueLenght_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROqueueLenght_64threads_avg_M2.get(n_try).append(float(avg))
            ROqueueLenght_64threads_std_M2.get(n_try).append(float(std))

        
# Put data of Waiting Time in corresponding Maps.

#Waiting Time
ROWaitingTime_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROWaitingTime_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROWaitingTime_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROWaitingTime_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROWaitingTime_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROWaitingTime_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROWaitingTime_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROWaitingTime_64threads_std_M2 = {1:[], 2:[], 3:[]}


for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'WaitingTime_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_8threads_avg_M2.get(n_try).append(float(avg))
            ROWaitingTime_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_16threads_avg_M2.get(n_try).append(float(avg))
            ROWaitingTime_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_32threads_avg_M2.get(n_try).append(float(avg))
            ROWaitingTime_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROWaitingTime_64threads_avg_M2.get(n_try).append(float(avg))
            ROWaitingTime_64threads_std_M2.get(n_try).append(float(std))
            
# Put data of Service Time in corresponding Maps.

#Service Time

ROServiceTime_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROServiceTime_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROServiceTime_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROServiceTime_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROServiceTime_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROServiceTime_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROServiceTime_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROServiceTime_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'ServiceTime_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_8threads_avg_M2.get(n_try).append(float(avg))
            ROServiceTime_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_16threads_avg_M2.get(n_try).append(float(avg))
            ROServiceTime_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_32threads_avg_M2.get(n_try).append(float(avg))
            ROServiceTime_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROServiceTime_64threads_avg_M2.get(n_try).append(float(avg))
            ROServiceTime_64threads_std_M2.get(n_try).append(float(std))
            
            
#Parse Time
ROParseTime_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROParseTime_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROParseTime_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROParseTime_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROParseTime_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROParseTime_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROParseTime_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROParseTime_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    filename_8threads = str(path_8threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T8_try'+str(n_try)
    filename_16threads = str(path_16threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T16_try'+str(n_try)
    filename_32threads = str(path_32threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T32_try'+str(n_try)
    filename_64threads = str(path_64threads_M2)+'ParseTime_E'+str(EXP)+str(MODE)+'OMidd2_T64_try'+str(n_try)

    filename_8threads = open(filename_8threads, "r")
    filename_16threads = open(filename_16threads, "r")
    filename_32threads = open(filename_32threads, "r")
    filename_64threads = open(filename_64threads, "r")

    for line in filename_8threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_8threads_avg_M2.get(n_try).append(float(avg))
            ROParseTime_8threads_std_M2.get(n_try).append(float(std))

        
    for line in filename_16threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_16threads_avg_M2.get(n_try).append(float(avg))
            ROParseTime_16threads_std_M2.get(n_try).append(float(std))

    for line in filename_32threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_32threads_avg_M2.get(n_try).append(float(avg))
            ROParseTime_32threads_std_M2.get(n_try).append(float(std))

    for line in filename_64threads:
        if(len(line.split())!=0):
            avg = line.split()[1][5: (5+int(len(line.split()[1][5:]))-1)]
            std = line.split()[2][5: (5+int(len(line.split()[1][5:]))-1)]
            ROParseTime_64threads_avg_M2.get(n_try).append(float(avg))
            ROParseTime_64threads_std_M2.get(n_try).append(float(std))

            

#Now calculate the following

ROlatencies_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROlatencies_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROlatencies_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROlatencies_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROlatencies_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROlatencies_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROlatencies_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROlatencies_64threads_std_M2 = {1:[], 2:[], 3:[]}

for n_try in [1, 2, 3]:
    for i in range(0,len(ROParseTime_8threads_avg_M2.get(n_try)),1):
        ROlatencies_8threads_avg_M2.get(n_try).append(    ROParseTime_8threads_avg_M2.get(n_try)[i] + 
                                                          ROWaitingTime_8threads_avg_M2.get(n_try)[i] +
                                                          ROServiceTime_8threads_avg_M2.get(n_try)[i]
                                                     )
        ROlatencies_8threads_std_M2.get(n_try).append(    ROParseTime_8threads_std_M2.get(n_try)[i] + 
                                                          ROWaitingTime_8threads_std_M2.get(n_try)[i] +
                                                          ROServiceTime_8threads_std_M2.get(n_try)[i]
                                                     )
    for i in range(0,len(ROParseTime_16threads_avg_M2.get(n_try)),1):       
        ROlatencies_16threads_avg_M2.get(n_try).append(   ROParseTime_16threads_avg_M2.get(n_try)[i] + 
                                                          ROWaitingTime_16threads_avg_M2.get(n_try)[i] +
                                                          ROServiceTime_16threads_avg_M2.get(n_try)[i]
                                                     )
        
        ROlatencies_16threads_std_M2.get(n_try).append(   ROParseTime_16threads_std_M2.get(n_try)[i] + 
                                                          ROWaitingTime_16threads_std_M2.get(n_try)[i] +
                                                          ROServiceTime_16threads_std_M2.get(n_try)[i]
                                                     )
    for i in range(0,len(ROParseTime_32threads_avg_M2.get(1)),1):               
        ROlatencies_32threads_avg_M2.get(n_try).append(   ROParseTime_32threads_avg_M2.get(n_try)[i] + 
                                                          ROWaitingTime_32threads_avg_M2.get(n_try)[i] +
                                                          ROServiceTime_32threads_avg_M2.get(n_try)[i]
                                                     )
        
        ROlatencies_32threads_std_M2.get(n_try).append(   ROParseTime_32threads_std_M2.get(n_try)[i] + 
                                                          ROWaitingTime_32threads_std_M2.get(n_try)[i] +
                                                          ROServiceTime_32threads_std_M2.get(n_try)[i]
                                                     )

    for i in range(0,len(ROParseTime_64threads_avg_M2.get(1)),1):               
        ROlatencies_64threads_avg_M2.get(n_try).append(   ROParseTime_64threads_avg_M2.get(n_try)[i] + 
                                                          ROWaitingTime_64threads_avg_M2.get(n_try)[i] +
                                                          ROServiceTime_64threads_avg_M2.get(n_try)[i]
                                                     )
        
        ROlatencies_64threads_std_M2.get(n_try).append(   ROParseTime_64threads_std_M2.get(n_try)[i] + 
                                                          ROWaitingTime_64threads_std_M2.get(n_try)[i] +
                                                          ROServiceTime_64threads_std_M2.get(n_try)[i]
                                                     )
        
        
ROlatencies_8threads_avg_M2 = np.mean([ ROlatencies_8threads_avg_M2.get(1), ROlatencies_8threads_avg_M2.get(2), ROlatencies_8threads_avg_M2.get(3) ], axis=0)
ROlatencies_8threads_std_M2 = np.mean([ ROlatencies_8threads_std_M2.get(1), ROlatencies_8threads_std_M2.get(2), ROlatencies_8threads_std_M2.get(3) ], axis=0)

ROlatencies_16threads_avg_M2 = np.mean([ ROlatencies_16threads_avg_M2.get(1), ROlatencies_16threads_avg_M2.get(2), ROlatencies_16threads_avg_M2.get(3) ], axis=0)
ROlatencies_16threads_std_M2 = np.mean([ ROlatencies_16threads_std_M2.get(1), ROlatencies_16threads_std_M2.get(2), ROlatencies_16threads_std_M2.get(3) ], axis=0)

ROlatencies_32threads_avg_M2 = np.mean([ ROlatencies_32threads_avg_M2.get(1), ROlatencies_32threads_avg_M2.get(2), ROlatencies_32threads_avg_M2.get(3) ], axis=0)
ROlatencies_32threads_std_M2 = np.mean([ ROlatencies_32threads_std_M2.get(1), ROlatencies_32threads_std_M2.get(2), ROlatencies_32threads_std_M2.get(3) ], axis=0)

ROlatencies_64threads_avg_M2 = np.mean([ ROlatencies_64threads_avg_M2.get(1), ROlatencies_64threads_avg_M2.get(2), ROlatencies_64threads_avg_M2.get(3) ], axis=0)
ROlatencies_64threads_std_M2 = np.mean([ ROlatencies_64threads_std_M2.get(1), ROlatencies_64threads_std_M2.get(2), ROlatencies_64threads_std_M2.get(3) ], axis=0)


ROthroughput_8threads_avg_M2 = np.mean([ ROthroughput_8threads_avg_M2.get(1), ROthroughput_8threads_avg_M2.get(2), ROthroughput_8threads_avg_M2.get(3) ], axis=0)
ROthroughput_8threads_std_M2 = np.mean([ ROthroughput_8threads_std_M2.get(1), ROthroughput_8threads_std_M2.get(2), ROthroughput_8threads_std_M2.get(3) ], axis=0)

ROthroughput_16threads_avg_M2 = np.mean([ ROthroughput_16threads_avg_M2.get(1), ROthroughput_16threads_avg_M2.get(2), ROthroughput_16threads_avg_M2.get(3) ], axis=0)
ROthroughput_16threads_std_M2 = np.mean([ ROthroughput_16threads_std_M2.get(1), ROthroughput_16threads_std_M2.get(2), ROthroughput_16threads_std_M2.get(3) ], axis=0)

ROthroughput_32threads_avg_M2 = np.mean([ ROthroughput_32threads_avg_M2.get(1), ROthroughput_32threads_avg_M2.get(2), ROthroughput_32threads_avg_M2.get(3) ], axis=0)
ROthroughput_32threads_std_M2 = np.mean([ ROthroughput_32threads_std_M2.get(1), ROthroughput_32threads_std_M2.get(2), ROthroughput_32threads_std_M2.get(3) ], axis=0)

ROthroughput_64threads_avg_M2 = np.mean([ ROthroughput_64threads_avg_M2.get(1), ROthroughput_64threads_avg_M2.get(2), ROthroughput_64threads_avg_M2.get(3) ], axis=0)
ROthroughput_64threads_std_M2 = np.mean([ ROthroughput_64threads_std_M2.get(1), ROthroughput_64threads_std_M2.get(2), ROthroughput_64threads_std_M2.get(3) ], axis=0)

ROqueueLenght_8threads_avg_M2 = np.mean([ ROqueueLenght_8threads_avg_M2.get(1), ROqueueLenght_8threads_avg_M2.get(2), ROqueueLenght_8threads_avg_M2.get(3) ], axis=0)
ROqueueLenght_8threads_std_M2 = np.mean([ ROqueueLenght_8threads_std_M2.get(1), ROqueueLenght_8threads_std_M2.get(2), ROqueueLenght_8threads_std_M2.get(3) ], axis=0)

ROqueueLenght_16threads_avg_M2 = np.mean([ ROqueueLenght_16threads_avg_M2.get(1), ROqueueLenght_16threads_avg_M2.get(2), ROqueueLenght_16threads_avg_M2.get(3) ], axis=0)
ROqueueLenght_16threads_std_M2 = np.mean([ ROqueueLenght_16threads_std_M2.get(1), ROqueueLenght_16threads_std_M2.get(2), ROqueueLenght_16threads_std_M2.get(3) ], axis=0)

ROqueueLenght_32threads_avg_M2 = np.mean([ ROqueueLenght_32threads_avg_M2.get(1), ROqueueLenght_32threads_avg_M2.get(2), ROqueueLenght_32threads_avg_M2.get(3) ], axis=0)
ROqueueLenght_32threads_std_M2 = np.mean([ ROqueueLenght_32threads_std_M2.get(1), ROqueueLenght_32threads_std_M2.get(2), ROqueueLenght_32threads_std_M2.get(3) ], axis=0)

ROqueueLenght_64threads_avg_M2 = np.mean([ ROqueueLenght_64threads_avg_M2.get(1), ROqueueLenght_64threads_avg_M2.get(2), ROqueueLenght_64threads_avg_M2.get(3) ], axis=0)
ROqueueLenght_64threads_std_M2 = np.mean([ ROqueueLenght_64threads_std_M2.get(1), ROqueueLenght_64threads_std_M2.get(2), ROqueueLenght_64threads_std_M2.get(3) ], axis=0)


ROService_time_8threads_avg_M2 = np.mean([ ROServiceTime_8threads_avg_M2.get(1),ROServiceTime_8threads_avg_M2.get(2),ROServiceTime_8threads_avg_M2.get(3) ], axis=0)
ROService_time_8threads_std_M2 = np.mean([ ROServiceTime_8threads_std_M2.get(1),ROServiceTime_8threads_std_M2.get(2),ROServiceTime_8threads_std_M2.get(3) ], axis=0)

ROService_time_16threads_avg_M2 = np.mean([ ROServiceTime_16threads_avg_M2.get(1),ROServiceTime_16threads_avg_M2.get(2),ROServiceTime_16threads_avg_M2.get(3) ], axis=0)
ROService_time_16threads_std_M2 = np.mean([ ROServiceTime_16threads_std_M2.get(1),ROServiceTime_16threads_std_M2.get(2),ROServiceTime_16threads_std_M2.get(3) ], axis=0)

ROService_time_32threads_avg_M2 = np.mean([ ROServiceTime_32threads_avg_M2.get(1),ROServiceTime_32threads_avg_M2.get(2),ROServiceTime_32threads_avg_M2.get(3) ], axis=0)
ROService_time_32threads_std_M2 = np.mean([ ROServiceTime_32threads_std_M2.get(1),ROServiceTime_32threads_std_M2.get(2),ROServiceTime_32threads_std_M2.get(3) ], axis=0)

ROService_time_64threads_avg_M2 = np.mean([ ROServiceTime_64threads_avg_M2.get(1),ROServiceTime_64threads_avg_M2.get(2),ROServiceTime_64threads_avg_M2.get(3) ], axis=0)
ROService_time_64threads_std_M2 = np.mean([ ROServiceTime_64threads_std_M2.get(1),ROServiceTime_64threads_std_M2.get(2),ROServiceTime_64threads_std_M2.get(3) ], axis=0)

ROWaiting_time_8threads_avg_M2 = np.mean([ ROWaitingTime_8threads_avg_M2.get(1),ROWaitingTime_8threads_avg_M2.get(2),ROWaitingTime_8threads_avg_M2.get(3) ], axis=0)
ROWaiting_time_8threads_std_M2 = np.mean([ ROWaitingTime_8threads_std_M2.get(1),ROWaitingTime_8threads_std_M2.get(2),ROWaitingTime_8threads_std_M2.get(3) ], axis=0)

ROWaiting_time_16threads_avg_M2 = np.mean([ ROWaitingTime_16threads_avg_M2.get(1),ROWaitingTime_16threads_avg_M2.get(2),ROWaitingTime_16threads_avg_M2.get(3) ], axis=0)
ROWaiting_time_16threads_std_M2 = np.mean([ ROWaitingTime_16threads_std_M2.get(1),ROWaitingTime_16threads_std_M2.get(2),ROWaitingTime_16threads_std_M2.get(3) ], axis=0)

ROWaiting_time_32threads_avg_M2 = np.mean([ ROWaitingTime_32threads_avg_M2.get(1),ROWaitingTime_32threads_avg_M2.get(2),ROWaitingTime_32threads_avg_M2.get(3) ], axis=0)
ROWaiting_time_32threads_std_M2 = np.mean([ ROWaitingTime_32threads_std_M2.get(1),ROWaitingTime_32threads_std_M2.get(2),ROWaitingTime_32threads_std_M2.get(3) ], axis=0)

ROWaiting_time_64threads_avg_M2 = np.mean([ ROWaitingTime_64threads_avg_M2.get(1),ROWaitingTime_64threads_avg_M2.get(2),ROWaitingTime_64threads_avg_M2.get(3) ], axis=0)
ROWaiting_time_64threads_std_M2 = np.mean([ ROWaitingTime_64threads_std_M2.get(1),ROWaitingTime_64threads_std_M2.get(2),ROWaitingTime_64threads_std_M2.get(3) ], axis=0)

# %%
ROideal_throughput_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_throughput_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROideal_throughput_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_throughput_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROideal_throughput_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_throughput_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROideal_throughput_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_throughput_64threads_std_M2 = {1:[], 2:[], 3:[]}



ROideal_latencies_8threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_latencies_8threads_std_M2 = {1:[], 2:[], 3:[]}

ROideal_latencies_16threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_latencies_16threads_std_M2 = {1:[], 2:[], 3:[]}

ROideal_latencies_32threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_latencies_32threads_std_M2 = {1:[], 2:[], 3:[]}

ROideal_latencies_64threads_avg_M2 = {1:[], 2:[], 3:[]}
ROideal_latencies_64threads_std_M2 = {1:[], 2:[], 3:[]}


for i in range(0,len(WOthroughput_8threads_avg_M2),1):
    ROideal_throughput_8threads_avg_M2[i] = (1/(ROlatencies_8threads_avg_M2[i]/1000))*(clients[i])
    ROideal_throughput_16threads_avg_M2[i] = (1/(ROlatencies_16threads_avg_M2[i]/1000))*(clients[i])
    ROideal_throughput_32threads_avg_M2[i] = (1/(ROlatencies_32threads_avg_M2[i]/1000))*(clients[i])
    ROideal_throughput_64threads_avg_M2[i] = (1/(ROlatencies_64threads_avg_M2[i]/1000))*(clients[i])

    ROideal_throughput_8threads_std_M2[i] = (1/(ROlatencies_8threads_std_M2[i]/1000))*(clients[i])
    ROideal_throughput_16threads_std_M2[i] = (1/(ROlatencies_16threads_std_M2[i]/1000))*(clients[i])
    ROideal_throughput_32threads_std_M2[i] = (1/(ROlatencies_32threads_std_M2[i]/1000))*(clients[i])
    ROideal_throughput_64threads_std_M2[i] = (1/(ROlatencies_64threads_std_M2[i]/1000))*(clients[i])

    
    ROideal_latencies_8threads_avg_M2[i] = 1000*(1/ROthroughput_8threads_avg_M2[i])*(clients[i])
    ROideal_latencies_16threads_avg_M2[i] = 1000*(1/ROthroughput_16threads_avg_M2[i])*(clients[i])
    ROideal_latencies_32threads_avg_M2[i] = 1000*(1/ROthroughput_32threads_avg_M2[i])*(clients[i])
    ROideal_latencies_64threads_avg_M2[i] = 1000*(1/ROthroughput_64threads_avg_M2[i])*(clients[i])
   

    ROideal_latencies_8threads_std_M2[i] = 1000*(1/ROthroughput_8threads_std_M2[i])*(clients[i])
    ROideal_latencies_16threads_std_M2[i] = 1000*(1/ROthroughput_16threads_std_M2[i])*(clients[i])
    ROideal_latencies_32threads_std_M2[i] = 1000*(1/ROthroughput_32threads_std_M2[i])*(clients[i])
    ROideal_latencies_64threads_std_M2[i] = 1000*(1/ROthroughput_64threads_std_M2[i])*(clients[i])

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a read-only workload measured in the middleware 2")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROthroughput_8threads_avg_M2, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROthroughput_16threads_avg_M2, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROthroughput_32threads_avg_M2, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROthroughput_64threads_avg_M2, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROthroughput_8threads_avg_M2, yerr=ROthroughput_8threads_std_M2, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_16threads_avg_M2, yerr=ROthroughput_16threads_std_M2, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_32threads_avg_M2, yerr=ROthroughput_32threads_std_M2, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_64threads_avg_M2, yerr=ROthroughput_64threads_std_M2, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ThroughputE32ROAllThreadsMiddleware2.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Queue Lenght')
plt.title("Queue Lenght of a read-only workload measured in the Middleware 2")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROqueueLenght_8threads_avg_M2, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROqueueLenght_16threads_avg_M2, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROqueueLenght_32threads_avg_M2, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROqueueLenght_64threads_avg_M2, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROqueueLenght_8threads_avg_M2, yerr=ROqueueLenght_8threads_std_M2, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_16threads_avg_M2, yerr=ROqueueLenght_16threads_std_M2, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_32threads_avg_M2, yerr=ROqueueLenght_32threads_std_M2, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_64threads_avg_M2, yerr=ROqueueLenght_64threads_std_M2, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("QueueLenghtE32ROAllThreadsMiddleware2.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Latencies (mse)')
plt.title("Latencies of a read-only workload measured in the Middleware 2")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROlatencies_8threads_avg_M2, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROlatencies_16threads_avg_M2, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROlatencies_32threads_avg_M2, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROlatencies_64threads_avg_M2, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROlatencies_8threads_avg_M2, yerr=ROlatencies_8threads_std_M2, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_16threads_avg_M2, yerr=ROlatencies_16threads_std_M2, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_32threads_avg_M2, yerr=ROlatencies_32threads_std_M2, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_64threads_avg_M2, yerr=ROlatencies_64threads_std_M2, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("LatenciesE32ROAllThreadsMiddleware2.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Service time (msec)')
plt.title("Service time measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROService_time_8threads_avg_M2, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROService_time_16threads_avg_M2, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROService_time_32threads_avg_M2, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROService_time_64threads_avg_M2, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROService_time_8threads_avg_M2, yerr=ROService_time_8threads_std_M2, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROService_time_16threads_avg_M2, yerr=ROService_time_16threads_std_M2, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROService_time_32threads_avg_M2, yerr=ROService_time_32threads_std_M2, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROService_time_64threads_avg_M2, yerr=ROService_time_64threads_std_M2, fmt=None, ecolor='yellow', capthick=1, capsize=4)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ServiceTimeE32ROAllThreadsMiddleware2.png", bbox_inches='tight')

# %% [markdown]
# ## NOW SUM MIDDLEWARE 1 AND 2 !!!

# %%
threads = 2
num_client_machines = 3
connections_per_thread = [1, 8, 16, 22, 28, 32]

clients = []

for c in connections_per_thread:
    clients.append(c*threads*num_client_machines)
clients

ROthroughput_8threads_avg_sum_middlewares = np.zeros(len(ROthroughput_8threads_avg_M1))
ROthroughput_8threads_std_sum_middlewares = np.zeros(len(ROthroughput_8threads_avg_M1))

ROthroughput_16threads_avg_sum_middlewares = np.zeros(len(ROthroughput_16threads_avg_M1))
ROthroughput_16threads_std_sum_middlewares = np.zeros(len(ROthroughput_16threads_avg_M1))

ROthroughput_32threads_avg_sum_middlewares = np.zeros(len(ROthroughput_32threads_avg_M1))
ROthroughput_32threads_std_sum_middlewares = np.zeros(len(ROthroughput_32threads_avg_M1))

ROthroughput_64threads_avg_sum_middlewares = np.zeros(len(ROthroughput_64threads_avg_M1))
ROthroughput_64threads_std_sum_middlewares = np.zeros(len(ROthroughput_64threads_avg_M1))

for i in range(0, len(ROthroughput_8threads_avg_M1),1):
    ROthroughput_8threads_avg_sum_middlewares[i] = ROthroughput_8threads_avg_M1[i]+ROthroughput_8threads_avg_M2[i]
    ROthroughput_8threads_std_sum_middlewares[i] = ROthroughput_8threads_std_M1[i]+ROthroughput_8threads_std_M2[i]
    
    ROthroughput_16threads_avg_sum_middlewares[i] = ROthroughput_16threads_avg_M1[i]+ROthroughput_16threads_avg_M2[i]
    ROthroughput_16threads_std_sum_middlewares[i] = ROthroughput_16threads_std_M1[i]+ROthroughput_16threads_std_M2[i]
    
    ROthroughput_32threads_avg_sum_middlewares[i] = ROthroughput_32threads_avg_M1[i]+ROthroughput_32threads_avg_M2[i]
    ROthroughput_32threads_std_sum_middlewares[i] = ROthroughput_32threads_std_M1[i]+ROthroughput_32threads_std_M2[i]
    
    ROthroughput_64threads_avg_sum_middlewares[i] = ROthroughput_64threads_avg_M1[i]+ROthroughput_64threads_avg_M2[i]
    ROthroughput_64threads_std_sum_middlewares[i] = ROthroughput_64threads_std_M1[i]+ROthroughput_64threads_std_M2[i]



ROqueueLenght_8threads_avg_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))
ROqueueLenght_8threads_std_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))

ROqueueLenght_16threads_avg_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))
ROqueueLenght_16threads_std_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))

ROqueueLenght_32threads_avg_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))
ROqueueLenght_32threads_std_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))

ROqueueLenght_64threads_avg_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))
ROqueueLenght_64threads_std_sum_middlewares = np.zeros(len(ROqueueLenght_8threads_avg_M2))

for i in range(0, len(ROthroughput_8threads_avg_M1),1):
    ROqueueLenght_8threads_avg_sum_middlewares[i] = ROqueueLenght_8threads_avg_M1[i]+ROqueueLenght_8threads_avg_M2[i]
    ROqueueLenght_8threads_std_sum_middlewares[i] = ROqueueLenght_8threads_std_M1[i]+ROqueueLenght_8threads_std_M2[i]
    
    ROqueueLenght_16threads_avg_sum_middlewares[i] = ROqueueLenght_16threads_avg_M1[i]+ROqueueLenght_16threads_avg_M2[i]
    ROqueueLenght_16threads_std_sum_middlewares[i] = ROqueueLenght_16threads_std_M1[i]+ROqueueLenght_16threads_std_M2[i]
    
    ROqueueLenght_32threads_avg_sum_middlewares[i] = ROqueueLenght_32threads_avg_M1[i]+ROqueueLenght_32threads_avg_M2[i]
    ROqueueLenght_32threads_std_sum_middlewares[i] = ROqueueLenght_32threads_std_M1[i]+ROqueueLenght_32threads_std_M2[i]
    
    ROqueueLenght_64threads_avg_sum_middlewares[i] = ROqueueLenght_64threads_avg_M1[i]+ROqueueLenght_64threads_avg_M2[i]
    ROqueueLenght_64threads_std_sum_middlewares[i] = ROqueueLenght_64threads_std_M1[i]+ROqueueLenght_64threads_std_M2[i]


    
ROlatencies_8threads_avg_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))
ROlatencies_8threads_std_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))

ROlatencies_16threads_avg_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))
ROlatencies_16threads_std_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))

ROlatencies_32threads_avg_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))
ROlatencies_32threads_std_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))

ROlatencies_64threads_avg_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))
ROlatencies_64threads_std_sum_middlewares = np.zeros(len(ROlatencies_8threads_avg_M1))

for i in range(0, len(ROthroughput_8threads_avg_M1),1):
    w1 = ROthroughput_8threads_avg_M1[i]/ROthroughput_8threads_avg_sum_middlewares[i]
    w2 = ROthroughput_8threads_avg_M2[i]/ROthroughput_8threads_avg_sum_middlewares[i]
    ROlatencies_8threads_avg_sum_middlewares[i] = ROlatencies_8threads_avg_M1[i]*w1 + ROlatencies_8threads_avg_M2[i]*w2
    ROlatencies_8threads_std_sum_middlewares[i] = ROlatencies_8threads_std_M1[i]*w1 +ROlatencies_8threads_std_M2[i]*w2

    w1 = ROthroughput_16threads_avg_M1[i]/ROthroughput_16threads_avg_sum_middlewares[i]
    w2 = ROthroughput_16threads_avg_M2[i]/ROthroughput_16threads_avg_sum_middlewares[i]
    ROlatencies_16threads_avg_sum_middlewares[i] = ROlatencies_16threads_avg_M1[i]*w1 +ROlatencies_16threads_avg_M2[i]*w2
    ROlatencies_16threads_std_sum_middlewares[i] = ROlatencies_16threads_std_M1[i]*w1 +ROlatencies_16threads_std_M2[i]*w2

    w1 = ROthroughput_32threads_avg_M1[i]/ROthroughput_32threads_avg_sum_middlewares[i]
    w2 = ROthroughput_32threads_avg_M2[i]/ROthroughput_32threads_avg_sum_middlewares[i]
    ROlatencies_32threads_avg_sum_middlewares[i] = ROlatencies_32threads_avg_M1[i]*w1 +ROlatencies_32threads_avg_M2[i]*w2
    ROlatencies_32threads_std_sum_middlewares[i] = ROlatencies_32threads_std_M1[i]*w1 +ROlatencies_32threads_std_M2[i]*w2
    
    w1 = ROthroughput_64threads_avg_M1[i]/ROthroughput_64threads_avg_sum_middlewares[i]
    w2 = ROthroughput_64threads_avg_M2[i]/ROthroughput_64threads_avg_sum_middlewares[i]
    ROlatencies_64threads_avg_sum_middlewares[i] = ROlatencies_64threads_avg_M1[i]*w1 +ROlatencies_64threads_avg_M2[i]*w2
    ROlatencies_64threads_std_sum_middlewares[i] = ROlatencies_64threads_std_M1[i]*w1 +ROlatencies_64threads_std_M2[i]*w2

    
    
num_elements = len(WOlatencies_8threads_avg_M1)
    
ROService_time_8threads_avg_sum_middlewares = np.zeros(num_elements)
ROService_time_8threads_std_sum_middlewares = np.zeros(num_elements)

ROService_time_16threads_avg_sum_middlewares = np.zeros(num_elements)
ROService_time_16threads_std_sum_middlewares = np.zeros(num_elements)

ROService_time_32threads_avg_sum_middlewares = np.zeros(num_elements)
ROService_time_32threads_std_sum_middlewares = np.zeros(num_elements)

ROService_time_64threads_avg_sum_middlewares = np.zeros(num_elements)
ROService_time_64threads_std_sum_middlewares = np.zeros(num_elements)

for i in range(0, len(ROthroughput_8threads_avg_M1),1):
    w1 = ROthroughput_8threads_avg_M1[i]/ROthroughput_8threads_avg_sum_middlewares[i]
    w2 = ROthroughput_8threads_avg_M2[i]/ROthroughput_8threads_avg_sum_middlewares[i]
    ROService_time_8threads_avg_sum_middlewares[i] = ROService_time_8threads_avg_M1[i]*w1 + ROService_time_8threads_avg_M2[i]*w2
    ROService_time_8threads_std_sum_middlewares[i] = ROService_time_8threads_std_M1[i]*w1 +ROService_time_8threads_std_M1[i]*w2

    w1 = ROthroughput_16threads_avg_M1[i]/ROthroughput_16threads_avg_sum_middlewares[i]
    w2 = ROthroughput_16threads_avg_M2[i]/ROthroughput_16threads_avg_sum_middlewares[i]
    ROService_time_16threads_avg_sum_middlewares[i] = ROService_time_16threads_avg_M1[i]*w1 +ROService_time_16threads_avg_M2[i]*w2
    ROService_time_16threads_std_sum_middlewares[i] = ROService_time_16threads_std_M1[i]*w1 +ROService_time_16threads_std_M2[i]*w2

    w1 = ROthroughput_32threads_avg_M1[i]/ROthroughput_32threads_avg_sum_middlewares[i]
    w2 = ROthroughput_32threads_avg_M2[i]/ROthroughput_32threads_avg_sum_middlewares[i]
    ROService_time_32threads_avg_sum_middlewares[i] = ROService_time_32threads_avg_M1[i]*w1 +ROService_time_32threads_avg_M2[i]*w2
    ROService_time_32threads_std_sum_middlewares[i] = ROService_time_32threads_std_M1[i]*w1 +ROService_time_32threads_std_M2[i]*w2
    
    w1 = ROthroughput_64threads_avg_M1[i]/ROthroughput_64threads_avg_sum_middlewares[i]
    w2 = ROthroughput_64threads_avg_M2[i]/ROthroughput_64threads_avg_sum_middlewares[i]
    ROService_time_64threads_avg_sum_middlewares[i] = ROService_time_64threads_avg_M1[i]*w1 +ROService_time_64threads_avg_M2[i]*w2
    ROService_time_64threads_std_sum_middlewares[i] = ROService_time_64threads_std_M1[i]*w1 +ROService_time_64threads_std_M2[i]*w2


    
ROWaiting_time_8threads_avg_sum_middlewares = np.zeros(num_elements)
ROWaiting_time_8threads_std_sum_middlewares = np.zeros(num_elements)

ROWaiting_time_16threads_avg_sum_middlewares = np.zeros(num_elements)
ROWaiting_time_16threads_std_sum_middlewares = np.zeros(num_elements)

ROWaiting_time_32threads_avg_sum_middlewares = np.zeros(num_elements)
ROWaiting_time_32threads_std_sum_middlewares = np.zeros(num_elements)

ROWaiting_time_64threads_avg_sum_middlewares = np.zeros(num_elements)
ROWaiting_time_64threads_std_sum_middlewares = np.zeros(num_elements)

for i in range(0, len(ROthroughput_8threads_avg_M1),1):
    w1 = ROthroughput_8threads_avg_M1[i]/ROthroughput_8threads_avg_sum_middlewares[i]
    w2 = ROthroughput_8threads_avg_M2[i]/ROthroughput_8threads_avg_sum_middlewares[i]
    ROWaiting_time_8threads_avg_sum_middlewares[i] = ROWaiting_time_8threads_avg_M1[i]*w1 + ROWaiting_time_8threads_avg_M2[i]*w2
    ROWaiting_time_8threads_std_sum_middlewares[i] = ROWaiting_time_8threads_std_M1[i]*w1 +ROWaiting_time_8threads_std_M2[i]*w2

    w1 = ROthroughput_16threads_avg_M1[i]/ROthroughput_16threads_avg_sum_middlewares[i]
    w2 = ROthroughput_16threads_avg_M2[i]/ROthroughput_16threads_avg_sum_middlewares[i]
    ROWaiting_time_16threads_avg_sum_middlewares[i] = ROWaiting_time_16threads_avg_M1[i]*w1 +ROWaiting_time_16threads_avg_M2[i]*w2
    ROWaiting_time_16threads_std_sum_middlewares[i] = ROWaiting_time_16threads_std_M1[i]*w1 +ROWaiting_time_16threads_std_M2[i]*w2

    w1 = ROthroughput_32threads_avg_M1[i]/ROthroughput_32threads_avg_sum_middlewares[i]
    w2 = ROthroughput_32threads_avg_M2[i]/ROthroughput_32threads_avg_sum_middlewares[i]
    ROWaiting_time_32threads_avg_sum_middlewares[i] = ROWaiting_time_32threads_avg_M1[i]*w1 +ROWaiting_time_32threads_avg_M2[i]*w2
    ROWaiting_time_32threads_std_sum_middlewares[i] = ROWaiting_time_32threads_std_M1[i]*w1 +ROWaiting_time_32threads_std_M2[i]*w2
    
    w1 = ROthroughput_64threads_avg_M1[i]/ROthroughput_64threads_avg_sum_middlewares[i]
    w2 = ROthroughput_64threads_avg_M2[i]/ROthroughput_64threads_avg_sum_middlewares[i]
    ROWaiting_time_64threads_avg_sum_middlewares[i] = ROWaiting_time_64threads_avg_M1[i]*w1 +ROWaiting_time_64threads_avg_M2[i]*w2
    ROWaiting_time_64threads_std_sum_middlewares[i] = ROWaiting_time_64threads_std_M1[i]*w1 +ROWaiting_time_64threads_std_M2[i]*w2

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Waiting time (msec)')
plt.title("Waiting time measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROWaiting_time_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROWaiting_time_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROWaiting_time_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROWaiting_time_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROWaiting_time_8threads_avg_sum_middlewares, yerr=ROWaiting_time_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROWaiting_time_16threads_avg_sum_middlewares, yerr=ROWaiting_time_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROWaiting_time_32threads_avg_sum_middlewares, yerr=ROWaiting_time_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROWaiting_time_64threads_avg_sum_middlewares, yerr=ROWaiting_time_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)
ax_lst.set_ylim(ymax=60)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("WaitingTimeE32ROAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Service time (msec)')
plt.title("Service time measured in the Middleware ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROService_time_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROService_time_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROService_time_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROService_time_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROService_time_8threads_avg_sum_middlewares, yerr=ROService_time_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROService_time_16threads_avg_sum_middlewares, yerr=ROService_time_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROService_time_32threads_avg_sum_middlewares, yerr=ROService_time_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROService_time_64threads_avg_sum_middlewares, yerr=ROService_time_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)
ax_lst.set_ylim(ymax=60)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ServiceTimeE32ROAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a read-only workload measured in both middlewares ")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROthroughput_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROthroughput_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROthroughput_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROthroughput_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)


ax_lst.errorbar(clients,ROthroughput_8threads_avg_sum_middlewares, yerr=ROthroughput_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_16threads_avg_sum_middlewares, yerr=ROthroughput_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_32threads_avg_sum_middlewares, yerr=ROthroughput_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_64threads_avg_sum_middlewares, yerr=ROthroughput_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)

ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)
ax_lst.set_ylim(ymax=4000)


plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("ThroughputE32ROAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Queue Lenght')
plt.title("Queue Lenght of a read-only workload measured in both middlewares")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROqueueLenght_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROqueueLenght_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROqueueLenght_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROqueueLenght_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)



ax_lst.errorbar(clients,ROqueueLenght_8threads_avg_sum_middlewares, yerr=ROqueueLenght_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_16threads_avg_sum_middlewares, yerr=ROqueueLenght_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_32threads_avg_sum_middlewares, yerr=ROqueueLenght_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROqueueLenght_64threads_avg_sum_middlewares, yerr=ROqueueLenght_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("QueueLenghtE32ROAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Latencies (mse)')
plt.title("Latencies of a read-only workload measured in both middlewares")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROlatencies_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_16T, = plt.plot(clients, ROlatencies_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_32T, = plt.plot(clients, ROlatencies_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_64T, = plt.plot(clients, ROlatencies_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)


ax_lst.errorbar(clients,ROlatencies_8threads_avg_sum_middlewares, yerr=ROlatencies_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_16threads_avg_sum_middlewares, yerr=ROlatencies_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_32threads_avg_sum_middlewares, yerr=ROlatencies_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROlatencies_64threads_avg_sum_middlewares, yerr=ROlatencies_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)
ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)

plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("LatenciesE32ROAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
ping_latencies = 1.3

ROideal_throughput_8threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_throughput_16threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_throughput_32threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_throughput_64threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))

ROideal_throughput_8threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_throughput_16threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_throughput_32threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_throughput_64threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))

ROideal_latencies_8threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_latencies_16threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_latencies_32threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_latencies_64threads_avg_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))

ROideal_latencies_8threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_latencies_16threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_latencies_32threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))
ROideal_latencies_64threads_std_sum_middleware = np.zeros((len(ROthroughput_8threads_avg_M1)))

for i in range(0,len(ROthroughput_8threads_avg_M1),1):
    ROideal_throughput_8threads_avg_sum_middleware[i] = (1/((ROlatencies_8threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    ROideal_throughput_16threads_avg_sum_middleware[i] = (1/((ROlatencies_16threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    ROideal_throughput_32threads_avg_sum_middleware[i] = (1/((ROlatencies_32threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    ROideal_throughput_64threads_avg_sum_middleware[i] = (1/((ROlatencies_64threads_avg_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])

    ROideal_throughput_8threads_std_sum_middleware[i] = (1/((ROlatencies_8threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    ROideal_throughput_16threads_std_sum_middleware[i] = (1/((ROlatencies_16threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    ROideal_throughput_32threads_std_sum_middleware[i] = (1/((ROlatencies_32threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])
    ROideal_throughput_64threads_std_sum_middleware[i] = (1/((ROlatencies_64threads_std_sum_middlewares[i]+ping_latencies)/1000))*(clients[i])

    
    ROideal_latencies_8threads_avg_sum_middleware[i] = 1000*(1/ROthroughput_8threads_avg_sum_middlewares[i])*(clients[i])
    ROideal_latencies_16threads_avg_sum_middleware[i] = 1000*(1/ROthroughput_16threads_avg_sum_middlewares[i])*(clients[i])
    ROideal_latencies_32threads_avg_sum_middleware[i] = 1000*(1/ROthroughput_32threads_avg_sum_middlewares[i])*(clients[i])
    ROideal_latencies_64threads_avg_sum_middleware[i] = 1000*(1/ROthroughput_64threads_avg_sum_middlewares[i])*(clients[i])
   

    ROideal_latencies_8threads_std_sum_middleware[i] = 1000*(1/ROthroughput_8threads_std_sum_middlewares[i])*(clients[i])
    ROideal_latencies_16threads_std_sum_middleware[i] = 1000*(1/ROthroughput_16threads_std_sum_middlewares[i])*(clients[i])
    ROideal_latencies_32threads_std_sum_middleware[i] = 1000*(1/ROthroughput_32threads_std_sum_middlewares[i])*(clients[i])
    ROideal_latencies_64threads_std_sum_middleware[i] = 1000*(1/ROthroughput_64threads_std_sum_middlewares[i])*(clients[i])

# %%
#USE clients
fig, ax_lst = plt.subplots(1, 1) 
plt.xlabel('Number of clients')
plt.ylabel('Throughput (ops/sec)')
plt.title("Throughput of a read-only workload measured in the middleware")
plt.grid('true', axis='both', fillstyle='left', linestyle='dashed',clip_on='true')
line_8T, = plt.plot(clients, ROthroughput_8threads_avg_sum_middlewares, color='blue', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_8T, = plt.plot(clients, ROideal_throughput_8threads_avg_sum_middleware, color='blue', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

line_16T, = plt.plot(clients, ROthroughput_16threads_avg_sum_middlewares, color='red', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_16T, = plt.plot(clients, ROideal_throughput_16threads_avg_sum_middleware, color='red', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

line_32T, = plt.plot(clients, ROthroughput_32threads_avg_sum_middlewares, color='green', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_32T, = plt.plot(clients, ROideal_throughput_32threads_avg_sum_middleware, color='green', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

line_64T, = plt.plot(clients, ROthroughput_64threads_avg_sum_middlewares, color='yellow', linestyle='solid', marker='o',markerfacecolor='blue', markersize=2)
line_ideal_64T, = plt.plot(clients, ROideal_throughput_64threads_avg_sum_middleware, color='yellow', linestyle='dashed', marker='o',markerfacecolor='blue', markersize=2)

ax_lst.errorbar(clients,ROthroughput_8threads_avg_sum_middlewares, yerr=ROthroughput_8threads_std_sum_middlewares, fmt=None, ecolor='blue', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_16threads_avg_sum_middlewares, yerr=ROthroughput_16threads_std_sum_middlewares, fmt=None, ecolor='red', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_32threads_avg_sum_middlewares, yerr=ROthroughput_32threads_std_sum_middlewares, fmt=None, ecolor='green', capthick=1, capsize=4)
ax_lst.errorbar(clients,ROthroughput_64threads_avg_sum_middlewares, yerr=ROthroughput_64threads_std_sum_middlewares, fmt=None, ecolor='yellow', capthick=1, capsize=4)

ax_lst.set_xlim(xmin=0)
ax_lst.set_ylim(ymin=0)
ax_lst.set_ylim(ymax=4000)


plt.legend([ line_8T, line_16T, line_32T, line_64T ], ['8 threads','16 threads', '32 threads', '64 threads'])
plt.savefig("IdealThroughputE32ROAllThreadsBOTHMiddlewares.png", bbox_inches='tight')

# %%
print(WOthroughput_64threads_avg_sum_middlewares)
print(WOlatencies_64threads_avg_sum_middlewares)
print(WOWaiting_time_64threads_avg_sum_middlewares)
# Out:
# [ 2948.27666667 10172.20666667 11311.39666667 13800.9
#  13841.06       14567.11666667]
# [ 1.30129502  4.04296646  6.23937691  8.01993128 10.89098101 11.69653419]
# [0.07643988 0.21775109 0.37379341 0.54364047 1.59041694 3.07935788]

# %%
print(ROthroughput_64threads_avg_sum_middlewares)
print(ROlatencies_64threads_avg_sum_middlewares)
print(ROWaiting_time_64threads_avg_sum_middlewares)
# Out:
# [2876.67       2896.24666667 2887.5        2884.87666667 2886.64666667
#  2890.38333333]
# [ 1.09053856 14.82236443 31.96821231 46.29558401 58.46253064 65.49035483]
# [ 0.06448882  0.35876024  0.37240393  1.43919691 11.57959296 19.16998096]
